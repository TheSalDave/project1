# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weather = pd.read_excel('Weather_Southampton_2018-01-01_to_2019-12-31.xlsx')
weather
# Out:
#               name             datetime  temp  feelslike  dew  humidity  \
# 0      southampton  2018-01-01T00:00:00   6.4        1.9  3.7     82.76
# 1      southampton  2018-01-01T01:00:00   6.6        2.4  3.4     80.14
# 2      southampton  2018-01-01T02:00:00   6.1        2.0  3.7     84.33
# 3      southampton  2018-01-01T03:00:00   6.0        1.6  2.9     80.44
# 4      southampton  2018-01-01T04:00:00   5.8        1.7  3.1     82.54
# ...            ...                  ...   ...        ...  ...       ...
# 17515  southampton  2019-12-31T19:00:00   7.1        4.1  5.3     88.21
# 17516  southampton  2019-12-31T20:00:00   6.8        3.7  5.1     88.52
# 17517  southampton  2019-12-31T21:00:00   6.5        3.3  4.7     88.23
# 17518  southampton  2019-12-31T22:00:00   6.6        4.4  4.7     87.69
# 17519  southampton  2019-12-31T23:00:00   6.7        4.1  4.8     88.13
#
#        precip  precipprob  preciptype  snow  ...  sealevelpressure  \
# ...

# %%
newweather = pd.DataFrame(np.repeat(weather.values, 2, axis=0))
newweather.columns = weather.columns
print(newweather)
# Out:
#               name             datetime temp feelslike  dew humidity precip  \
# 0      southampton  2018-01-01T00:00:00  6.4       1.9  3.7    82.76   0.56
# 1      southampton  2018-01-01T00:00:00  6.4       1.9  3.7    82.76   0.56
# 2      southampton  2018-01-01T01:00:00  6.6       2.4  3.4    80.14    NaN
# 3      southampton  2018-01-01T01:00:00  6.6       2.4  3.4    80.14    NaN
# 4      southampton  2018-01-01T02:00:00  6.1       2.0  3.7    84.33    NaN
# ...            ...                  ...  ...       ...  ...      ...    ...
# 35035  southampton  2019-12-31T21:00:00  6.5       3.3  4.7    88.23    NaN
# 35036  southampton  2019-12-31T22:00:00  6.6       4.4  4.7    87.69    NaN
# 35037  southampton  2019-12-31T22:00:00  6.6       4.4  4.7    87.69    NaN
# 35038  southampton  2019-12-31T23:00:00  6.7       4.1  4.8    88.13    NaN
# 35039  southampton  2019-12-31T23:00:00  6.7       4.1  4.8    88.13    NaN
#
# ...

# %%
newweather.to_excel("DoubleWeather.xlsx")
