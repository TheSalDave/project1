# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Redoing model selection with validation set

# %%
df = pd.read_excel("BaseFeaturesDE.xlsx")
df = df.drop('Unnamed: 0', axis = 1)
df
# Out:
#            From Timestamp  DE Electricity (kWh)  dayofweek  hour  holiday  \
# 0     2018-05-10 09:30:00                 332.0          3   9.5        0
# 1     2018-05-10 10:00:00                 332.0          3  10.0        0
# 2     2018-05-10 10:30:00                 334.0          3  10.5        0
# 3     2018-05-10 11:00:00                 334.0          3  11.0        0
# 4     2018-05-10 11:30:00                 337.0          3  11.5        0
# ...                   ...                   ...        ...   ...      ...
# 28824 2019-12-31 21:30:00                 227.0          1  21.5        0
# 28825 2019-12-31 22:00:00                 227.0          1  22.0        0
# 28826 2019-12-31 22:30:00                 226.0          1  22.5        0
# 28827 2019-12-31 23:00:00                 228.0          1  23.0        0
# 28828 2019-12-31 23:30:00                 230.0          1  23.5        0
#
#        month  Temperature (C)  Feels like (C)  Humidity (%)
# 0          5             12.0            12.0         61.88
# 1          5             12.8            12.8         58.50
# 2          5             12.8            12.8         58.50
# 3          5             13.3            13.3         55.36
# 4          5             13.3            13.3         55.36
# ...      ...              ...             ...           ...
# 28824     12              6.5             3.3         88.23
# 28825     12              6.6             4.4         87.69
# 28826     12              6.6             4.4         87.69
# 28827     12              6.7             4.1         88.13
# 28828     12              6.7             4.1         88.13
#
# [28829 rows x 9 columns]

# %% [markdown]
# # First by splitting it according to time
# The splitting will be 60:20:20

# %%
lagNumberStart = 1
lagNumberEnd = 8

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    df[name] = df['DE Electricity (kWh)'].shift(48*i)

i = list(range(lagNumberEnd*48))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting

size = -int(len(df)*0.2)

Xinput = df.iloc[:size]
Xtest = df.iloc[size:] # 20%

size2 = -int(len(Xinput)*0.25)

Xtrain = Xinput.iloc[:size2].copy() #60%
Xvalidate = Xinput.iloc[size2:].copy() #20%

trainX = Xtrain[feature_cols] # Features
trainy = Xtrain['DE Electricity (kWh)'] # Target variable

validateX = Xvalidate[feature_cols] # Features
validatey = Xvalidate['DE Electricity (kWh)'] # Target variable

testX = Xtest[feature_cols] # Features
testy = Xtest['DE Electricity (kWh)'] # Target variable

inputX = Xinput[feature_cols] # Features
inputy = Xinput['DE Electricity (kWh)'] # Target variable

scaler = StandardScaler() #scaling
scaler.fit(X)
trainXscaled = scaler.transform(trainX)
validateXscaled = scaler.transform(validateX)
testXscaled = scaler.transform(testX)
inputXscaled = scaler.transform(inputX)

# %%
print(len(trainXscaled))
print(len(validateXscaled))
print(len(testXscaled))
print(len(inputXscaled))
# Out:
# 17067
# 5689
# 5689
# 22756

# %% [markdown]
# # Random Forest Regressor

# %%
N = range(10,1011,100)

RFR = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR.fit(inputXscaled, inputy)

RFR_results = pd.DataFrame(RFR.cv_results_)
RFR_results = RFR_results[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFR_results
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 10               1010         0.694693                1
# 9                 910         0.694504                2
# 8                 810         0.693998                3
# 1                 110         0.693416                4
# 7                 710         0.693100                5
# 6                 610         0.692856                6
# 5                 510         0.692852                7
# 4                 410         0.692617                8
# 2                 210         0.691762                9
# 3                 310         0.691748               10
# 0                  10         0.681205               11

# %%
N = range(5,96,10)

RFR1 = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR1.fit(inputXscaled, inputy)

RFRresults1 = pd.DataFrame(RFR1.cv_results_)
RFRresults1 = RFRresults1[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFRresults1
# Out:
#   param_n_estimators  mean_test_score  rank_test_score
# 6                 65         0.692381                1
# 9                 95         0.692293                2
# 5                 55         0.690619                3
# 4                 45         0.690235                4
# 8                 85         0.690107                5
# 7                 75         0.689644                6
# 3                 35         0.688531                7
# 2                 25         0.688239                8
# 1                 15         0.677475                9
# 0                  5         0.669259               10

# %%
RFRresults2 = RFR_results.copy()
RFRresults = RFRresults2.append(RFRresults1)
RFRresults = RFRresults.sort_values(by=['mean_test_score'])
RFRresults
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 0                   5         0.669259               10
# 1                  15         0.677475                9
# 0                  10         0.681205               11
# 2                  25         0.688239                8
# 3                  35         0.688531                7
# 7                  75         0.689644                6
# 8                  85         0.690107                5
# 4                  45         0.690235                4
# 5                  55         0.690619                3
# 3                 310         0.691748               10
# 2                 210         0.691762                9
# 9                  95         0.692293                2
# 6                  65         0.692381                1
# 4                 410         0.692617                8
# 5                 510         0.692852                7
# 6                 610         0.692856                6
# 7                 710         0.693100                5
# 1                 110         0.693416                4
# 8                 810         0.693998                3
# 9                 910         0.694504                2
# 10               1010         0.694693                1

# %%
RFRresults = RFRresults.sort_values(by=['param_n_estimators'])
plt.plot(RFRresults['param_n_estimators'], RFRresults['mean_test_score'])

plt.xlabel('Number of Trees')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores of different number of trees for Random Forest')
# Display a figure.
plt.show()

# %%
estimator = RandomForestRegressor(n_estimators = 1510,  random_state=42, max_depth=5).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions on DE')
# Display a figure.
plt.show()
# Out:
# 4.266034246816634

# %%
pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(RandomForestMAPE)

plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xticks(rotation=45)
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 5.34099188175684

# %% [markdown]
# # Visualization examples

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+700], df['From Timestamp'].iloc[size+1600])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# #### What the hell is going on here?

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+2300], df['From Timestamp'].iloc[size+2800])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # Another still existant outlier found at the exact same spot as for HH.

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+4500], df['From Timestamp'].iloc[size+5688])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %%
error = 100*(pred - testy)/testy
plt.hist(error, bins=100)
plt.title('Distribution of Random Forest Regressor prediction errors')
plt.xlabel('Prediction Error in %')
_ = plt.ylabel('Count')

# %% [markdown]
# # KNN

# %%
N = range(1,150,1)

KNN = GridSearchCV(KNeighborsRegressor(), {
    'n_neighbors': N,
    'weights': ['uniform', 'distance']
}, cv=5, return_train_score=False, verbose = 3)
KNN.fit(inputXscaled, inputy)
KNN_results = pd.DataFrame(KNN.cv_results_)
KNN_results = KNN_results[['param_n_neighbors', 'param_weights', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
KNN_results
# Out:
# Fitting 5 folds for each of 298 candidates, totalling 1490 fits
# [CV 1/5] END .................n_neighbors=1, weights=uniform; total time=   0.7s
# [CV 2/5] END .................n_neighbors=1, weights=uniform; total time=   0.7s
# [CV 3/5] END .................n_neighbors=1, weights=uniform; total time=   0.7s
# [CV 4/5] END .................n_neighbors=1, weights=uniform; total time=   1.0s
# [CV 5/5] END .................n_neighbors=1, weights=uniform; total time=   0.8s
# [CV 1/5] END ................n_neighbors=1, weights=distance; total time=   0.7s
# [CV 2/5] END ................n_neighbors=1, weights=distance; total time=   0.7s
# [CV 3/5] END ................n_neighbors=1, weights=distance; total time=   0.8s
# [CV 4/5] END ................n_neighbors=1, weights=distance; total time=   1.0s
# [CV 5/5] END ................n_neighbors=1, weights=distance; total time=   0.9s
# [CV 1/5] END .................n_neighbors=2, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=2, weights=uniform; total time=   0.7s
# [CV 3/5] END .................n_neighbors=2, weights=uniform; total time=   0.8s
# [CV 4/5] END .................n_neighbors=2, weights=uniform; total time=   1.0s
# [CV 5/5] END .................n_neighbors=2, weights=uniform; total time=   1.1s
# [CV 1/5] END ................n_neighbors=2, weights=distance; total time=   0.7s
# [CV 2/5] END ................n_neighbors=2, weights=distance; total time=   0.7s
# [CV 3/5] END ................n_neighbors=2, weights=distance; total time=   0.8s
# [CV 4/5] END ................n_neighbors=2, weights=distance; total time=   1.0s
# [CV 5/5] END ................n_neighbors=2, weights=distance; total time=   0.8s
# [CV 1/5] END .................n_neighbors=3, weights=uniform; total time=   0.7s
# [CV 2/5] END .................n_neighbors=3, weights=uniform; total time=   0.7s
# [CV 3/5] END .................n_neighbors=3, weights=uniform; total time=   0.8s
# [CV 4/5] END .................n_neighbors=3, weights=uniform; total time=   1.1s
# [CV 5/5] END .................n_neighbors=3, weights=uniform; total time=   0.8s
# [CV 1/5] END ................n_neighbors=3, weights=distance; total time=   0.7s
# [CV 2/5] END ................n_neighbors=3, weights=distance; total time=   0.7s
# [CV 3/5] END ................n_neighbors=3, weights=distance; total time=   0.8s
# [CV 4/5] END ................n_neighbors=3, weights=distance; total time=   1.1s
# [CV 5/5] END ................n_neighbors=3, weights=distance; total time=   0.8s
# [CV 1/5] END .................n_neighbors=4, weights=uniform; total time=   0.7s
# [CV 2/5] END .................n_neighbors=4, weights=uniform; total time=   0.7s
# [CV 3/5] END .................n_neighbors=4, weights=uniform; total time=   0.9s
# [CV 4/5] END .................n_neighbors=4, weights=uniform; total time=   1.1s
# [CV 5/5] END .................n_neighbors=4, weights=uniform; total time=   0.9s
# [CV 1/5] END ................n_neighbors=4, weights=distance; total time=   0.7s
# [CV 2/5] END ................n_neighbors=4, weights=distance; total time=   0.7s
# [CV 3/5] END ................n_neighbors=4, weights=distance; total time=   0.8s
# [CV 4/5] END ................n_neighbors=4, weights=distance; total time=   1.1s
# [CV 5/5] END ................n_neighbors=4, weights=distance; total time=   0.9s
# [CV 1/5] END .................n_neighbors=5, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=5, weights=uniform; total time=   0.8s
# [CV 3/5] END .................n_neighbors=5, weights=uniform; total time=   0.9s
# [CV 4/5] END .................n_neighbors=5, weights=uniform; total time=   1.1s
# [CV 5/5] END .................n_neighbors=5, weights=uniform; total time=   0.9s
# [CV 1/5] END ................n_neighbors=5, weights=distance; total time=   0.8s
# [CV 2/5] END ................n_neighbors=5, weights=distance; total time=   0.8s
# [CV 3/5] END ................n_neighbors=5, weights=distance; total time=   0.9s
# [CV 4/5] END ................n_neighbors=5, weights=distance; total time=   1.1s
# [CV 5/5] END ................n_neighbors=5, weights=distance; total time=   0.9s
# [CV 1/5] END .................n_neighbors=6, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=6, weights=uniform; total time=   0.8s
# [CV 3/5] END .................n_neighbors=6, weights=uniform; total time=   0.9s
# [CV 4/5] END .................n_neighbors=6, weights=uniform; total time=   1.1s
# [CV 5/5] END .................n_neighbors=6, weights=uniform; total time=   0.9s
# [CV 1/5] END ................n_neighbors=6, weights=distance; total time=   0.9s
# [CV 2/5] END ................n_neighbors=6, weights=distance; total time=   0.9s
# [CV 3/5] END ................n_neighbors=6, weights=distance; total time=   0.9s
# [CV 4/5] END ................n_neighbors=6, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=6, weights=distance; total time=   1.1s
# [CV 1/5] END .................n_neighbors=7, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=7, weights=uniform; total time=   0.8s
# [CV 3/5] END .................n_neighbors=7, weights=uniform; total time=   1.0s
# [CV 4/5] END .................n_neighbors=7, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=7, weights=uniform; total time=   1.0s
# [CV 1/5] END ................n_neighbors=7, weights=distance; total time=   0.8s
# [CV 2/5] END ................n_neighbors=7, weights=distance; total time=   0.8s
# [CV 3/5] END ................n_neighbors=7, weights=distance; total time=   1.0s
# [CV 4/5] END ................n_neighbors=7, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=7, weights=distance; total time=   0.9s
# [CV 1/5] END .................n_neighbors=8, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=8, weights=uniform; total time=   0.8s
# [CV 3/5] END .................n_neighbors=8, weights=uniform; total time=   1.0s
# [CV 4/5] END .................n_neighbors=8, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=8, weights=uniform; total time=   1.0s
# [CV 1/5] END ................n_neighbors=8, weights=distance; total time=   0.8s
# [CV 2/5] END ................n_neighbors=8, weights=distance; total time=   0.8s
# [CV 3/5] END ................n_neighbors=8, weights=distance; total time=   0.9s
# [CV 4/5] END ................n_neighbors=8, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=8, weights=distance; total time=   0.9s
# [CV 1/5] END .................n_neighbors=9, weights=uniform; total time=   0.8s
# [CV 2/5] END .................n_neighbors=9, weights=uniform; total time=   0.8s
# [CV 3/5] END .................n_neighbors=9, weights=uniform; total time=   0.9s
# [CV 4/5] END .................n_neighbors=9, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=9, weights=uniform; total time=   1.0s
# [CV 1/5] END ................n_neighbors=9, weights=distance; total time=   0.8s
# [CV 2/5] END ................n_neighbors=9, weights=distance; total time=   0.8s
# [CV 3/5] END ................n_neighbors=9, weights=distance; total time=   1.0s
# [CV 4/5] END ................n_neighbors=9, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=9, weights=distance; total time=   0.9s
# [CV 1/5] END ................n_neighbors=10, weights=uniform; total time=   0.8s
# [CV 2/5] END ................n_neighbors=10, weights=uniform; total time=   0.8s
# [CV 3/5] END ................n_neighbors=10, weights=uniform; total time=   1.0s
# [CV 4/5] END ................n_neighbors=10, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=10, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=10, weights=distance; total time=   0.8s
# [CV 2/5] END ...............n_neighbors=10, weights=distance; total time=   0.8s
# [CV 3/5] END ...............n_neighbors=10, weights=distance; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=10, weights=distance; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=10, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=11, weights=uniform; total time=   0.8s
# [CV 2/5] END ................n_neighbors=11, weights=uniform; total time=   0.8s
# [CV 3/5] END ................n_neighbors=11, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=11, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=11, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=11, weights=distance; total time=   0.8s
# [CV 2/5] END ...............n_neighbors=11, weights=distance; total time=   0.8s
# [CV 3/5] END ...............n_neighbors=11, weights=distance; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=11, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=11, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=12, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=12, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=12, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=12, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=12, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=12, weights=distance; total time=   0.8s
# [CV 2/5] END ...............n_neighbors=12, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=12, weights=distance; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=12, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=12, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=13, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=13, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=13, weights=uniform; total time=   1.0s
# [CV 4/5] END ................n_neighbors=13, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=13, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=13, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=13, weights=distance; total time=   0.8s
# [CV 3/5] END ...............n_neighbors=13, weights=distance; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=13, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=13, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=14, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=14, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=14, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=14, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=14, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=14, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=14, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=14, weights=distance; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=14, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=14, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=15, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=15, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=15, weights=uniform; total time=   1.0s
# [CV 4/5] END ................n_neighbors=15, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=15, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=15, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=15, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=15, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=15, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=15, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=16, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=16, weights=uniform; total time=   1.3s
# [CV 3/5] END ................n_neighbors=16, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=16, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=16, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=16, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=16, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=16, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=16, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=16, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=17, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=17, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=17, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=17, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=17, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=17, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=17, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=17, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=17, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=17, weights=distance; total time=   1.0s
# [CV 1/5] END ................n_neighbors=18, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=18, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=18, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=18, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=18, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=18, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=18, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=18, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=18, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=18, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=19, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=19, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=19, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=19, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=19, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=19, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=19, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=19, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=19, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=19, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=20, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=20, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=20, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=20, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=20, weights=uniform; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=20, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=20, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=20, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=20, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=20, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=21, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=21, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=21, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=21, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=21, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=21, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=21, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=21, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=21, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=21, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=22, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=22, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=22, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=22, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=22, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=22, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=22, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=22, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=22, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=22, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=23, weights=uniform; total time=   0.9s
# [CV 2/5] END ................n_neighbors=23, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=23, weights=uniform; total time=   1.1s
# [CV 4/5] END ................n_neighbors=23, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=23, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=23, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=23, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=23, weights=distance; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=23, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=23, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=24, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=24, weights=uniform; total time=   0.9s
# [CV 3/5] END ................n_neighbors=24, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=24, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=24, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=24, weights=distance; total time=   0.9s
# [CV 2/5] END ...............n_neighbors=24, weights=distance; total time=   0.9s
# [CV 3/5] END ...............n_neighbors=24, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=24, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=24, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=25, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=25, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=25, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=25, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=25, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=25, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=25, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=25, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=25, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=25, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=26, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=26, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=26, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=26, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=26, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=26, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=26, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=26, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=26, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=26, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=27, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=27, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=27, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=27, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=27, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=27, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=27, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=27, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=27, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=27, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=28, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=28, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=28, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=28, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=28, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=28, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=28, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=28, weights=distance; total time=   1.5s
# [CV 4/5] END ...............n_neighbors=28, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=28, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=29, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=29, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=29, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=29, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=29, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=29, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=29, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=29, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=29, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=29, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=30, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=30, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=30, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=30, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=30, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=30, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=30, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=30, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=30, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=30, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=31, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=31, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=31, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=31, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=31, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=31, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=31, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=31, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=31, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=31, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=32, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=32, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=32, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=32, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=32, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=32, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=32, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=32, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=32, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=32, weights=distance; total time=   1.1s
# [CV 1/5] END ................n_neighbors=33, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=33, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=33, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=33, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=33, weights=uniform; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=33, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=33, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=33, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=33, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=33, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=34, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=34, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=34, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=34, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=34, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=34, weights=distance; total time=   1.0s
# [CV 2/5] END ...............n_neighbors=34, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=34, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=34, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=34, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=35, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=35, weights=uniform; total time=   1.0s
# [CV 3/5] END ................n_neighbors=35, weights=uniform; total time=   1.2s
# [CV 4/5] END ................n_neighbors=35, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=35, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=35, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=35, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=35, weights=distance; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=35, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=35, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=36, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=36, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=36, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=36, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=36, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=36, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=36, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=36, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=36, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=36, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=37, weights=uniform; total time=   1.0s
# [CV 2/5] END ................n_neighbors=37, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=37, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=37, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=37, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=37, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=37, weights=distance; total time=   1.0s
# [CV 3/5] END ...............n_neighbors=37, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=37, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=37, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=38, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=38, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=38, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=38, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=38, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=38, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=38, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=38, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=38, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=38, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=39, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=39, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=39, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=39, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=39, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=39, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=39, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=39, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=39, weights=distance; total time=   2.0s
# [CV 5/5] END ...............n_neighbors=39, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=40, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=40, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=40, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=40, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=40, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=40, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=40, weights=distance; total time=   1.3s
# [CV 3/5] END ...............n_neighbors=40, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=40, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=40, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=41, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=41, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=41, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=41, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=41, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=41, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=41, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=41, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=41, weights=distance; total time=   2.0s
# [CV 5/5] END ...............n_neighbors=41, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=42, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=42, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=42, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=42, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=42, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=42, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=42, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=42, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=42, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=42, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=43, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=43, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=43, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=43, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=43, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=43, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=43, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=43, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=43, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=43, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=44, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=44, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=44, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=44, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=44, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=44, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=44, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=44, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=44, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=44, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=45, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=45, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=45, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=45, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=45, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=45, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=45, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=45, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=45, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=45, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=46, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=46, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=46, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=46, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=46, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=46, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=46, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=46, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=46, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=46, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=47, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=47, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=47, weights=uniform; total time=   1.3s
# [CV 4/5] END ................n_neighbors=47, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=47, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=47, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=47, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=47, weights=distance; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=47, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=47, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=48, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=48, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=48, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=48, weights=uniform; total time=   1.9s
# [CV 5/5] END ................n_neighbors=48, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=48, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=48, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=48, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=48, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=48, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=49, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=49, weights=uniform; total time=   1.4s
# [CV 3/5] END ................n_neighbors=49, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=49, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=49, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=49, weights=distance; total time=   1.1s
# [CV 2/5] END ...............n_neighbors=49, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=49, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=49, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=49, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=50, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=50, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=50, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=50, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=50, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=50, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=50, weights=distance; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=50, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=50, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=50, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=51, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=51, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=51, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=51, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=51, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=51, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=51, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=51, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=51, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=51, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=52, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=52, weights=uniform; total time=   1.1s
# [CV 3/5] END ................n_neighbors=52, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=52, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=52, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=52, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=52, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=52, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=52, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=52, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=53, weights=uniform; total time=   1.1s
# [CV 2/5] END ................n_neighbors=53, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=53, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=53, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=53, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=53, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=53, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=53, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=53, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=53, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=54, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=54, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=54, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=54, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=54, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=54, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=54, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=54, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=54, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=54, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=55, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=55, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=55, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=55, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=55, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=55, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=55, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=55, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=55, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=55, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=56, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=56, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=56, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=56, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=56, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=56, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=56, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=56, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=56, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=56, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=57, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=57, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=57, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=57, weights=uniform; total time=   2.1s
# [CV 5/5] END ................n_neighbors=57, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=57, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=57, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=57, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=57, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=57, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=58, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=58, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=58, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=58, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=58, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=58, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=58, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=58, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=58, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=58, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=59, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=59, weights=uniform; total time=   1.2s
# [CV 3/5] END ................n_neighbors=59, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=59, weights=uniform; total time=   1.8s
# [CV 5/5] END ................n_neighbors=59, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=59, weights=distance; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=59, weights=distance; total time=   1.2s
# [CV 3/5] END ...............n_neighbors=59, weights=distance; total time=   1.4s
# [CV 4/5] END ...............n_neighbors=59, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=59, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=60, weights=uniform; total time=   1.2s
# ...
# [CV 5/5] END ...............n_neighbors=131, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=131, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=131, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=131, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=131, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=131, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=132, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=132, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=132, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=132, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=132, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=132, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=132, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=132, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=132, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=132, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=133, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=133, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=133, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=133, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=133, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=133, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=133, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=133, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=133, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=133, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=134, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=134, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=134, weights=uniform; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=134, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=134, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=134, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=134, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=134, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=134, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=134, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=135, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=135, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=135, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=135, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=135, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=135, weights=distance; total time=   1.7s
# [CV 2/5] END ..............n_neighbors=135, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=135, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=135, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=135, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=136, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=136, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=136, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=136, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=136, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=136, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=136, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=136, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=136, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=136, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=137, weights=uniform; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=137, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=137, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=137, weights=uniform; total time=   2.4s
# [CV 5/5] END ...............n_neighbors=137, weights=uniform; total time=   1.8s
# [CV 1/5] END ..............n_neighbors=137, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=137, weights=distance; total time=   1.9s
# [CV 3/5] END ..............n_neighbors=137, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=137, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=137, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=138, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=138, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=138, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=138, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=138, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=138, weights=distance; total time=   1.9s
# [CV 2/5] END ..............n_neighbors=138, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=138, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=138, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=138, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=139, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=139, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=139, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=139, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=139, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=139, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=139, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=139, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=139, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=139, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=140, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=140, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=140, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=140, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=140, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=140, weights=distance; total time=   1.8s
# [CV 2/5] END ..............n_neighbors=140, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=140, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=140, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=140, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=141, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=141, weights=uniform; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=141, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=141, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=141, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=141, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=141, weights=distance; total time=   1.8s
# [CV 3/5] END ..............n_neighbors=141, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=141, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=141, weights=distance; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=142, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=142, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=142, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=142, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=142, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=142, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=142, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=142, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=142, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=142, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=143, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=143, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=143, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=143, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=143, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=143, weights=distance; total time=   1.7s
# [CV 2/5] END ..............n_neighbors=143, weights=distance; total time=   1.9s
# [CV 3/5] END ..............n_neighbors=143, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=143, weights=distance; total time=   2.5s
# [CV 5/5] END ..............n_neighbors=143, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=144, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=144, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=144, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=144, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=144, weights=uniform; total time=   1.6s
# [CV 1/5] END ..............n_neighbors=144, weights=distance; total time=   1.7s
# [CV 2/5] END ..............n_neighbors=144, weights=distance; total time=   1.6s
# [CV 3/5] END ..............n_neighbors=144, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=144, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=144, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=145, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=145, weights=uniform; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=145, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=145, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=145, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=145, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=145, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=145, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=145, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=145, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=146, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=146, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=146, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=146, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=146, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=146, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=146, weights=distance; total time=   1.8s
# [CV 3/5] END ..............n_neighbors=146, weights=distance; total time=   2.0s
# [CV 4/5] END ..............n_neighbors=146, weights=distance; total time=   2.6s
# [CV 5/5] END ..............n_neighbors=146, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=147, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=147, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=147, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=147, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=147, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=147, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=147, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=147, weights=distance; total time=   1.9s
# [CV 4/5] END ..............n_neighbors=147, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=147, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=148, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=148, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=148, weights=uniform; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=148, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=148, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=148, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=148, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=148, weights=distance; total time=   2.0s
# [CV 4/5] END ..............n_neighbors=148, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=148, weights=distance; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=149, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=149, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=149, weights=uniform; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=149, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=149, weights=uniform; total time=   1.7s
# [CV 1/5] END ..............n_neighbors=149, weights=distance; total time=   1.6s
# [CV 2/5] END ..............n_neighbors=149, weights=distance; total time=   1.7s
# [CV 3/5] END ..............n_neighbors=149, weights=distance; total time=   2.1s
# [CV 4/5] END ..............n_neighbors=149, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=149, weights=distance; total time=   2.0s
#     param_n_neighbors param_weights  mean_test_score  rank_test_score
# 199               100      distance         0.735534                1
# 201               101      distance         0.735495                2
# 197                99      distance         0.735468                3
# 203               102      distance         0.735454                4
# 211               106      distance         0.735447                5
# ..                ...           ...              ...              ...
# 5                   3      distance         0.609337              294
# 3                   2      distance         0.589830              295
# 2                   2       uniform         0.589736              296
# 1                   1      distance         0.564016              297
# 0                   1       uniform         0.564016              298
#
# [298 rows x 4 columns]

# %%
KNNuniform = KNN_results[(KNN_results['param_weights'] == 'uniform' )].sort_values(by = ['param_n_neighbors'])
KNNdistance = KNN_results[(KNN_results['param_weights'] == 'distance' )].sort_values(by = ['param_n_neighbors'])

plt.plot(KNNuniform['param_n_neighbors'], KNNuniform['mean_test_score'], label = 'uniform')
plt.plot(KNNdistance['param_n_neighbors'], KNNdistance['mean_test_score'], label = 'distance')

plt.xlabel('Param N Neighbors')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores for different parameter combinations of kNN')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
estimator = KNeighborsRegressor(n_neighbors = 100, weights = 'distance').fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

KNNMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions on DE')
# Display a figure.
plt.show()
# Out:
# 4.468061528744434

# %%
plt.title('KNN predictions on DE')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()

# %% [markdown]
# # SVM Regression

# %%
SVM = GridSearchCV(svm.SVR(gamma='scale'), {
    'C': [0.01, 0.1, 1, 100], 
    'kernel': ['rbf','linear'],
    'epsilon': [0.01,0.1,1,10]
}, cv=5, return_train_score=False, verbose = 4)
SVM.fit(inputXscaled, inputy)

svm_results = pd.DataFrame(SVM.cv_results_)
svmresults = svm_results[['param_kernel','param_C','param_epsilon', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
svmresults
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  31.2s
# [CV 2/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  32.0s
# [CV 3/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  31.4s
# [CV 4/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  31.8s
# [CV 5/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  31.0s
# [CV 1/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  17.5s
# [CV 2/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  16.7s
# [CV 3/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  16.8s
# [CV 4/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  17.7s
# [CV 5/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  17.2s
# [CV 1/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.0s
# [CV 2/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  32.0s
# [CV 3/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.1s
# [CV 4/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.9s
# [CV 5/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.5s
# [CV 1/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  17.0s
# [CV 2/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  16.6s
# [CV 3/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  16.7s
# [CV 4/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  17.3s
# [CV 5/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  16.6s
# [CV 1/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.7s
# [CV 2/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.5s
# [CV 3/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.7s
# [CV 4/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.3s
# [CV 5/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.9s
# [CV 1/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.2s
# [CV 2/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.2s
# [CV 3/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.7s
# [CV 4/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.3s
# [CV 5/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.9s
# [CV 1/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.4s
# [CV 2/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.5s
# [CV 3/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  28.8s
# [CV 4/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  27.7s
# [CV 5/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  27.7s
# [CV 1/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  10.2s
# [CV 2/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  10.5s
# [CV 3/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  10.3s
# [CV 4/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   9.6s
# [CV 5/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   9.5s
# [CV 1/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  31.6s
# [CV 2/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  31.2s
# [CV 3/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  31.6s
# [CV 4/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  31.4s
# [CV 5/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  32.6s
# [CV 1/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  17.2s
# [CV 2/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  17.3s
# [CV 3/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  18.5s
# [CV 4/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  17.6s
# [CV 5/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  17.3s
# [CV 1/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  31.7s
# [CV 2/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  31.1s
# [CV 3/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  31.5s
# [CV 4/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  31.5s
# [CV 5/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  31.8s
# [CV 1/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  17.3s
# [CV 2/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  17.0s
# [CV 3/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  18.0s
# [CV 4/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  17.3s
# [CV 5/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  17.2s
# [CV 1/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.5s
# [CV 2/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.2s
# [CV 3/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.5s
# [CV 4/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.1s
# [CV 5/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.3s
# [CV 1/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.5s
# [CV 2/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.4s
# [CV 3/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  17.0s
# [CV 4/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.3s
# [CV 5/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.3s
# [CV 1/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  22.9s
# [CV 2/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  22.3s
# [CV 3/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  21.7s
# [CV 4/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  21.4s
# [CV 5/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  21.2s
# [CV 1/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   9.5s
# [CV 2/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   9.4s
# [CV 3/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  10.1s
# [CV 4/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   9.0s
# [CV 5/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   8.9s
# [CV 1/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  32.0s
# [CV 2/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  32.7s
# [CV 3/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  33.1s
# [CV 4/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  31.9s
# [CV 5/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  32.3s
# [CV 1/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  19.1s
# [CV 2/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  18.6s
# [CV 3/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  19.1s
# [CV 4/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  18.8s
# [CV 5/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  18.3s
# [CV 1/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  32.1s
# [CV 2/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  31.7s
# [CV 3/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  32.0s
# [CV 4/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  31.7s
# [CV 5/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  32.4s
# [CV 1/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  19.0s
# [CV 2/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  18.8s
# [CV 3/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  18.8s
# [CV 4/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  18.3s
# [CV 5/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  18.3s
# [CV 1/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.8s
# [CV 2/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.3s
# [CV 3/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.9s
# [CV 4/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.3s
# [CV 5/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  30.0s
# [CV 1/5] END ..................C=1, epsilon=1, kernel=linear; total time=  17.8s
# [CV 2/5] END ..................C=1, epsilon=1, kernel=linear; total time=  21.1s
# [CV 3/5] END ..................C=1, epsilon=1, kernel=linear; total time=  18.1s
# [CV 4/5] END ..................C=1, epsilon=1, kernel=linear; total time=  17.4s
# [CV 5/5] END ..................C=1, epsilon=1, kernel=linear; total time=  17.3s
# [CV 1/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  17.0s
# [CV 2/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  16.4s
# [CV 3/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  15.8s
# [CV 4/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  13.6s
# [CV 5/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  18.4s
# [CV 1/5] END .................C=1, epsilon=10, kernel=linear; total time=  11.0s
# [CV 2/5] END .................C=1, epsilon=10, kernel=linear; total time=  12.4s
# [CV 3/5] END .................C=1, epsilon=10, kernel=linear; total time=  10.6s
# [CV 4/5] END .................C=1, epsilon=10, kernel=linear; total time=   9.5s
# [CV 5/5] END .................C=1, epsilon=10, kernel=linear; total time=  10.0s
# [CV 1/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  45.3s
# [CV 2/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  45.1s
# [CV 3/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  44.6s
# [CV 4/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  45.5s
# [CV 5/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  46.3s
# [CV 1/5] END .............C=100, epsilon=0.01, kernel=linear; total time= 2.0min
# [CV 2/5] END .............C=100, epsilon=0.01, kernel=linear; total time= 1.8min
# [CV 3/5] END .............C=100, epsilon=0.01, kernel=linear; total time= 1.6min
# [CV 4/5] END .............C=100, epsilon=0.01, kernel=linear; total time= 1.6min
# [CV 5/5] END .............C=100, epsilon=0.01, kernel=linear; total time= 1.5min
# [CV 1/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  47.8s
# [CV 2/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  43.9s
# [CV 3/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  48.1s
# [CV 4/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  45.3s
# [CV 5/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  45.8s
# [CV 1/5] END ..............C=100, epsilon=0.1, kernel=linear; total time= 1.9min
# [CV 2/5] END ..............C=100, epsilon=0.1, kernel=linear; total time= 1.9min
# [CV 3/5] END ..............C=100, epsilon=0.1, kernel=linear; total time= 1.7min
# [CV 4/5] END ..............C=100, epsilon=0.1, kernel=linear; total time= 1.5min
# [CV 5/5] END ..............C=100, epsilon=0.1, kernel=linear; total time= 1.5min
# [CV 1/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  39.5s
# [CV 2/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  38.4s
# [CV 3/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  38.6s
# [CV 4/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  39.2s
# [CV 5/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  40.1s
# [CV 1/5] END ................C=100, epsilon=1, kernel=linear; total time= 1.8min
# [CV 2/5] END ................C=100, epsilon=1, kernel=linear; total time= 1.8min
# [CV 3/5] END ................C=100, epsilon=1, kernel=linear; total time= 1.6min
# [CV 4/5] END ................C=100, epsilon=1, kernel=linear; total time= 1.4min
# [CV 5/5] END ................C=100, epsilon=1, kernel=linear; total time= 1.5min
# [CV 1/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  11.9s
# [CV 2/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  11.4s
# [CV 3/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  12.0s
# [CV 4/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   9.9s
# [CV 5/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   9.9s
# [CV 1/5] END ...............C=100, epsilon=10, kernel=linear; total time=  57.7s
# [CV 2/5] END ...............C=100, epsilon=10, kernel=linear; total time=  58.0s
# [CV 3/5] END ...............C=100, epsilon=10, kernel=linear; total time=  54.4s
# [CV 4/5] END ...............C=100, epsilon=10, kernel=linear; total time=  50.1s
# [CV 5/5] END ...............C=100, epsilon=10, kernel=linear; total time=  52.3s
#    param_kernel param_C param_epsilon  mean_test_score  rank_test_score
# 28          rbf     100             1         0.774138                1
# 26          rbf     100           0.1         0.773795                2
# 24          rbf     100          0.01         0.773756                3
# 30          rbf     100            10         0.760757                4
# 16          rbf       1          0.01         0.740989                5
# 18          rbf       1           0.1         0.740983                6
# 20          rbf       1             1         0.740556                7
# 22          rbf       1            10         0.733426                8
# 7        linear    0.01            10         0.704492                9
# 1        linear    0.01          0.01         0.700026               10
# 3        linear    0.01           0.1         0.700021               11
# 5        linear    0.01             1         0.699940               12
# 15       linear     0.1            10         0.690666               13
# 23       linear       1            10         0.686905               14
# 31       linear     100            10         0.686257               15
# 13       linear     0.1             1         0.669804               16
# 9        linear     0.1          0.01         0.669067               17
# 11       linear     0.1           0.1         0.669025               18
# 21       linear       1             1         0.657760               19
# 19       linear       1           0.1         0.657118               20
# 17       linear       1          0.01         0.657103               21
# 29       linear     100             1         0.656414               22
# 27       linear     100           0.1         0.656316               23
# 25       linear     100          0.01         0.656167               24
# 10          rbf     0.1           0.1         0.545866               25
# 8           rbf     0.1          0.01         0.545864               26
# 12          rbf     0.1             1         0.545582               27
# 14          rbf     0.1            10         0.543755               28
# 6           rbf    0.01            10        -0.020945               29
# 0           rbf    0.01          0.01        -0.032823               30
# 2           rbf    0.01           0.1        -0.032937               31
# 4           rbf    0.01             1        -0.033535               32

# %%
#from sklearn.model_selection import train_test_split

#X_train,X_test,y_train,y_test = train_test_split(X1scaled,y1,test_size=0.25,random_state=42) #split training:testing 75:25


estimator = svm.SVR(C = 100,  kernel = 'rbf', epsilon = 1).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions on DE')
# Display a figure.
plt.show()
# Out:
# 2.8729771423771666

# %%
pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(SVMMAPE)

plt.title('SVM predictions on DE')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 2.8729771423771666

# %% [markdown]
# # Inspecting/visualizing

# %%
plt.title('SVM predictions on DE Electricity')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+2300], df['From Timestamp'].iloc[size+3300])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# #### First big spike is an outlier. Second strange shape is an entire missing day. I suspect the missing day caused the incorrect spike in the predictions on a weekend.

# %%
plt.title('SVM predictions on DE Electricity')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+3300], df['From Timestamp'].iloc[size+4500])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %%
plt.title('SVM predictions on DE Electricity')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+4500], df['From Timestamp'].iloc[size+5688])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # The next parts are used to find points of interest for 2.4 SHAP

# %%
plt.title('SVM predictions on DE Electricity')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+5364], df['From Timestamp'].iloc[size+5380])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %%
plt.title('SVM predictions on DE Electricity')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+503], df['From Timestamp'].iloc[size+555])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %%
df[(df['Temperature (C)']==22.2) & (df['dayofweek']==6)]
# Out:
#            From Timestamp  DE Electricity (kWh)  dayofweek  hour  holiday  \
# 1169  2018-06-03 18:00:00                 242.0          6  18.0        0
# 1170  2018-06-03 18:30:00                 237.0          6  18.5        0
# 23677 2019-09-15 16:00:00                 229.0          6  16.0        0
# 23678 2019-09-15 16:30:00                 230.0          6  16.5        0
#
#        month  Temperature (C)  Feels like (C)  Humidity (%)  n-48.  n-96.  \
# 1169       6             22.2            22.2         49.45  241.0  293.0
# 1170       6             22.2            22.2         49.45  237.0  291.0
# 23677      9             22.2            22.2         63.58  218.0  330.0
# 23678      9             22.2            22.2         63.58  218.0  322.0
#
#        n-144.  n-192.  n-240.  n-288.  n-336.
# 1169    296.0   296.0   276.0   264.0   225.0
# 1170    292.0   296.0   276.0   264.0   223.0
# 23677   346.1   326.0   325.0   314.0   220.0
# 23678   336.9   345.0   329.0   303.0   218.0

# %% [markdown]
# # Multilayer perceptron

# %%
from sklearn.neural_network import MLPRegressor

layers = range(1,30)

parameters = {'hidden_layer_sizes': layers, 'solver': ['lbfgs', 'adam'], 'max_iter': [3000], 'learning_rate_init': 10.0 ** -np.arange(1, 6, 2), 'random_state':[42]}
MLPReg = GridSearchCV(MLPRegressor(), parameters, cv=5,  verbose=2, return_train_score=False)
MLPReg.fit(inputXscaled, inputy)

MLPRegRes = pd.DataFrame(MLPReg.cv_results_)
MLP_results = MLPRegRes[['rank_test_score', 'mean_test_score', 'param_hidden_layer_sizes', 'param_solver', 'param_max_iter', 'param_learning_rate_init']].sort_values(by=['rank_test_score'])
MLP_results
# Out:
# Fitting 5 folds for each of 174 candidates, totalling 870 fits
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.7s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.4s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.9s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.2min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.2min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.2min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.2min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.2min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.1s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.7s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.6s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.7s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   9.6s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   8.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.9min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   6.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   8.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.7s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  23.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  31.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  28.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  28.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  28.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.3s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  38.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  33.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  20.3s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  29.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  30.3s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.9s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  23.0s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  40.0s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  37.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  24.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  21.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.8s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.3s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  29.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  48.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  16.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  31.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  22.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.3s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.9s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.4s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.5s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  46.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.0min
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  48.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  34.5s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.4s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  14.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  14.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  15.4s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  14.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.4s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  28.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  42.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  20.8s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  36.5s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  48.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  12.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  12.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  15.7s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.7s
# ...
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  42.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  40.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  42.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  43.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.1s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   3.7s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   3.2s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.9s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  43.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.2s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  53.1s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.0min
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  56.7s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time= 1.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  43.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  44.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
#     rank_test_score  mean_test_score param_hidden_layer_sizes param_solver  \
# 63                1         0.787944                       11         adam
# 22                2         0.782358                        4        lbfgs
# 20                2         0.782358                        4        lbfgs
# 18                2         0.782358                        4        lbfgs
# 28                5         0.778818                        5        lbfgs
# ..              ...              ...                      ...          ...
# 23              170       -12.372802                        4         adam
# 17              171       -12.395922                        3         adam
# 41              172       -13.367193                        7         adam
# 11              173       -18.476795                        2         adam
# 5               174       -21.256757                        1         adam
#
#    param_max_iter param_learning_rate_init
# 63           3000                    0.001
# 22           3000                  0.00001
# 20           3000                    0.001
# 18           3000                      0.1
# 28           3000                  0.00001
# ..            ...                      ...
# 23           3000                  0.00001
# 17           3000                  0.00001
# 41           3000                  0.00001
# 11           3000                  0.00001
# 5            3000                  0.00001
#
# [174 rows x 6 columns]

# %%
MLP_results1 = MLP_results[MLP_results['mean_test_score']>0.5]


MLP_adam = MLP_results1[(MLP_results1['param_solver'] == 'adam' )].sort_values(by = ['param_hidden_layer_sizes'])
MLP_lbfgs = MLP_results1[(MLP_results1['param_solver'] == 'lbfgs' )].sort_values(by = ['param_hidden_layer_sizes'])

plt.plot(MLP_adam['param_hidden_layer_sizes'], MLP_adam['mean_test_score'], label = 'adam')
plt.plot(MLP_lbfgs['param_hidden_layer_sizes'], MLP_lbfgs['mean_test_score'], label = 'lbfgs')

plt.xlabel('Number of hidden layers')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores of different number of hidden layers for Multi Layer Perceptron')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
estimator = MLPRegressor(hidden_layer_sizes=11, solver = 'adam', max_iter=3000, learning_rate_init=0.001, random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions on DE')
# Display a figure.
plt.show()
# Out:
# 3.597035476229746

# %%
estimator = MLPRegressor(hidden_layer_sizes=5, solver = 'lbfgs', max_iter=3000, learning_rate_init=0.00001, random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions on DE')
# Display a figure.
plt.show()
# Out:
# 3.976854485796083

# %%
pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(MLPMAPE)

plt.title('Multi Layer Perceptron predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 3.597035476229746

# %% [markdown]
# # Random Split

# %%
df = pd.read_excel("BaseFeaturesDE.xlsx")
df = df.drop('Unnamed: 0', axis = 1)

lagNumberStart = 1
lagNumberEnd = 8

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    df[name] = df['DE Electricity (kWh)'].shift(48*i)

i = list(range(lagNumberEnd*48))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting
Y = df[['DE Electricity (kWh)']]


scaler = StandardScaler() #scaling
scaler.fit(X)
Xscaled = scaler.transform(X)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Xscaled,Y,test_size=0.20,random_state=42) #split training:testing 80:20

# %%
estimator = RandomForestRegressor(n_estimators = 1500,  random_state=42).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

RandomForestMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()
# Out:
# <ipython-input-45-9f1ddba3d58d>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator = RandomForestRegressor(n_estimators = 1500,  random_state=42).fit(X_train, y_train)
# 2.3077988182398763

# %%
estimator = KNeighborsRegressor(n_neighbors = 100, weights = 'distance').fit(X_train, y_train)
y_pred = estimator.predict(X_test)

KNNMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions')
# Display a figure.
plt.show()
# Out:
# 4.122870134444141

# %%
estimator = svm.SVR(C = 100,  kernel = 'rbf', epsilon = 0.001).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

SVMMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 2.8741178921857635

# %%
from sklearn.neural_network import MLPRegressor
estimator = MLPRegressor(hidden_layer_sizes=11, solver = 'lbfgs', max_iter=3000, learning_rate_init=0.001, random_state=42).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

MLPMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 4.99032176038922
