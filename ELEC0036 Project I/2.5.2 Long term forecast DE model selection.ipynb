# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Model selection for long term forecasts

# %%
df = pd.read_excel("BaseFeaturesDE.xlsx")
df = df.drop('Unnamed: 0', axis = 1)
df
# Out:
#            From Timestamp  DE Electricity (kWh)  dayofweek  hour  holiday  \
# 0     2018-05-10 09:30:00                 332.0          3   9.5        0
# 1     2018-05-10 10:00:00                 332.0          3  10.0        0
# 2     2018-05-10 10:30:00                 334.0          3  10.5        0
# 3     2018-05-10 11:00:00                 334.0          3  11.0        0
# 4     2018-05-10 11:30:00                 337.0          3  11.5        0
# ...                   ...                   ...        ...   ...      ...
# 28824 2019-12-31 21:30:00                 227.0          1  21.5        0
# 28825 2019-12-31 22:00:00                 227.0          1  22.0        0
# 28826 2019-12-31 22:30:00                 226.0          1  22.5        0
# 28827 2019-12-31 23:00:00                 228.0          1  23.0        0
# 28828 2019-12-31 23:30:00                 230.0          1  23.5        0
#
#        month  Temperature (C)  Feels like (C)  Humidity (%)
# 0          5             12.0            12.0         61.88
# 1          5             12.8            12.8         58.50
# 2          5             12.8            12.8         58.50
# 3          5             13.3            13.3         55.36
# 4          5             13.3            13.3         55.36
# ...      ...              ...             ...           ...
# 28824     12              6.5             3.3         88.23
# 28825     12              6.6             4.4         87.69
# 28826     12              6.6             4.4         87.69
# 28827     12              6.7             4.1         88.13
# 28828     12              6.7             4.1         88.13
#
# [28829 rows x 9 columns]

# %% [markdown]
# # First by splitting it according to time
# The splitting will be 60:20:20

# %%
feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   
    
X = df[feature_cols].copy() #input features for fitting

size = -int(len(df)*0.2)

Xinput = df.iloc[:size]
Xtest = df.iloc[size:] # 20%

size2 = -int(len(Xinput)*0.25)

Xtrain = Xinput.iloc[:size2].copy() #60%
Xvalidate = Xinput.iloc[size2:].copy() #20%

trainX = Xtrain[feature_cols] # Features
trainy = Xtrain['DE Electricity (kWh)'] # Target variable

validateX = Xvalidate[feature_cols] # Features
validatey = Xvalidate['DE Electricity (kWh)'] # Target variable

testX = Xtest[feature_cols] # Features
testy = Xtest['DE Electricity (kWh)'] # Target variable

inputX = Xinput[feature_cols] # Features
inputy = Xinput['DE Electricity (kWh)'] # Target variable

scaler = StandardScaler() #scaling
scaler.fit(X)
trainXscaled = scaler.transform(trainX)
validateXscaled = scaler.transform(validateX)
testXscaled = scaler.transform(testX)
inputXscaled = scaler.transform(inputX)

# %%
print(len(trainXscaled))
print(len(validateXscaled))
print(len(testXscaled))
print(len(inputXscaled))
# Out:
# 21024
# 7008
# 7008
# 28032

# %% [markdown]
# # Random Forest Regressor

# %%
N = range(10,1011,100)

RFR = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR.fit(inputXscaled, inputy)

RFR_results = pd.DataFrame(RFR.cv_results_)
RFR_results = RFR_results[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFR_results
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 10               1010        -0.275331                1
# 9                 910        -0.276215                2
# 4                 410        -0.276229                3
# 7                 710        -0.277006                4
# 5                 510        -0.277218                5
# 6                 610        -0.277345                6
# 8                 810        -0.277495                7
# 3                 310        -0.279046                8
# 2                 210        -0.279818                9
# 1                 110        -0.280093               10
# 0                  10        -0.302016               11

# %%
N = range(5,96,10)

RFR1 = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR1.fit(inputXscaled, inputy)

RFRresults1 = pd.DataFrame(RFR1.cv_results_)
RFRresults1 = RFRresults1[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFRresults1
# Out:
#   param_n_estimators  mean_test_score  rank_test_score
# 4                 45        -0.266592                1
# 3                 35        -0.271534                2
# 2                 25        -0.271795                3
# 5                 55        -0.273867                4
# 6                 65        -0.276259                5
# 7                 75        -0.276911                6
# 8                 85        -0.278095                7
# 9                 95        -0.279368                8
# 1                 15        -0.282019                9
# 0                  5        -0.320211               10

# %%
RFRresults2 = RFR_results.copy()
RFRresults = RFRresults2.append(RFRresults1)
RFRresults = RFRresults.sort_values(by=['mean_test_score'])
RFRresults
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 0                   5        -0.320211               10
# 0                  10        -0.302016               11
# 1                  15        -0.282019                9
# 1                 110        -0.280093               10
# 2                 210        -0.279818                9
# 9                  95        -0.279368                8
# 3                 310        -0.279046                8
# 8                  85        -0.278095                7
# 8                 810        -0.277495                7
# 6                 610        -0.277345                6
# 5                 510        -0.277218                5
# 7                 710        -0.277006                4
# 7                  75        -0.276911                6
# 6                  65        -0.276259                5
# 4                 410        -0.276229                3
# 9                 910        -0.276215                2
# 10               1010        -0.275331                1
# 5                  55        -0.273867                4
# 2                  25        -0.271795                3
# 3                  35        -0.271534                2
# 4                  45        -0.266592                1

# %%
RFRresults = RFRresults.sort_values(by=['param_n_estimators'])
plt.plot(RFRresults['param_n_estimators'], RFRresults['mean_test_score'])

plt.xlabel('Number of Trees')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores of different number of trees for Random Forest')
# Display a figure.
plt.show()

# %%
estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()
# Out:
# 7.746338302959364

# %%
pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(RandomForestMAPE)

plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 7.746338302959364

# %% [markdown]
# # Visualization examples

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+4914], df['From Timestamp'].iloc[size+4964])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# Looks decent but on other parts:

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.plot(df['From Timestamp'].iloc[size:],df['Feels like (C)'].iloc[size:], label = "Feels like (C)")
plt.xlim(df['From Timestamp'].iloc[size+1200], df['From Timestamp'].iloc[size+1700])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # KNN

# %%
N = range(1,350,1)

KNN = GridSearchCV(KNeighborsRegressor(), {
    'n_neighbors': N,
    'weights': ['uniform', 'distance']
}, cv=5, return_train_score=False, verbose = 3)
KNN.fit(inputXscaled, inputy)
KNN_results = pd.DataFrame(KNN.cv_results_)
KNN_results = KNN_results[['param_n_neighbors', 'param_weights', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
KNN_results
# Out:
# Fitting 5 folds for each of 698 candidates, totalling 3490 fits
# [CV 1/5] END .................n_neighbors=1, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=1, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=1, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=1, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=1, weights=uniform; total time=   0.2s
# [CV 1/5] END ................n_neighbors=1, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=1, weights=distance; total time=   0.4s
# [CV 3/5] END ................n_neighbors=1, weights=distance; total time=   0.6s
# [CV 4/5] END ................n_neighbors=1, weights=distance; total time=   0.4s
# [CV 5/5] END ................n_neighbors=1, weights=distance; total time=   0.3s
# [CV 1/5] END .................n_neighbors=2, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=2, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=2, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=2, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=2, weights=uniform; total time=   0.4s
# [CV 1/5] END ................n_neighbors=2, weights=distance; total time=   0.4s
# [CV 2/5] END ................n_neighbors=2, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=2, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=2, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=2, weights=distance; total time=   0.4s
# [CV 1/5] END .................n_neighbors=3, weights=uniform; total time=   0.4s
# [CV 2/5] END .................n_neighbors=3, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=3, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=3, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=3, weights=uniform; total time=   0.2s
# [CV 1/5] END ................n_neighbors=3, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=3, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=3, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=3, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=3, weights=distance; total time=   0.4s
# [CV 1/5] END .................n_neighbors=4, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=4, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=4, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=4, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=4, weights=uniform; total time=   0.3s
# [CV 1/5] END ................n_neighbors=4, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=4, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=4, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=4, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=4, weights=distance; total time=   0.2s
# [CV 1/5] END .................n_neighbors=5, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=5, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=5, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=5, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=5, weights=uniform; total time=   0.3s
# [CV 1/5] END ................n_neighbors=5, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=5, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=5, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=5, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=5, weights=distance; total time=   0.3s
# [CV 1/5] END .................n_neighbors=6, weights=uniform; total time=   0.4s
# [CV 2/5] END .................n_neighbors=6, weights=uniform; total time=   0.4s
# [CV 3/5] END .................n_neighbors=6, weights=uniform; total time=   0.4s
# [CV 4/5] END .................n_neighbors=6, weights=uniform; total time=   0.4s
# [CV 5/5] END .................n_neighbors=6, weights=uniform; total time=   0.4s
# [CV 1/5] END ................n_neighbors=6, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=6, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=6, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=6, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=6, weights=distance; total time=   0.3s
# [CV 1/5] END .................n_neighbors=7, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=7, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=7, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=7, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=7, weights=uniform; total time=   0.3s
# [CV 1/5] END ................n_neighbors=7, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=7, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=7, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=7, weights=distance; total time=   0.5s
# [CV 5/5] END ................n_neighbors=7, weights=distance; total time=   0.3s
# [CV 1/5] END .................n_neighbors=8, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=8, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=8, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=8, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=8, weights=uniform; total time=   0.3s
# [CV 1/5] END ................n_neighbors=8, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=8, weights=distance; total time=   0.3s
# [CV 3/5] END ................n_neighbors=8, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=8, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=8, weights=distance; total time=   0.3s
# [CV 1/5] END .................n_neighbors=9, weights=uniform; total time=   0.3s
# [CV 2/5] END .................n_neighbors=9, weights=uniform; total time=   0.3s
# [CV 3/5] END .................n_neighbors=9, weights=uniform; total time=   0.3s
# [CV 4/5] END .................n_neighbors=9, weights=uniform; total time=   0.3s
# [CV 5/5] END .................n_neighbors=9, weights=uniform; total time=   0.3s
# [CV 1/5] END ................n_neighbors=9, weights=distance; total time=   0.3s
# [CV 2/5] END ................n_neighbors=9, weights=distance; total time=   0.4s
# [CV 3/5] END ................n_neighbors=9, weights=distance; total time=   0.3s
# [CV 4/5] END ................n_neighbors=9, weights=distance; total time=   0.3s
# [CV 5/5] END ................n_neighbors=9, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=10, weights=uniform; total time=   0.3s
# [CV 2/5] END ................n_neighbors=10, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=10, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=10, weights=uniform; total time=   0.3s
# [CV 5/5] END ................n_neighbors=10, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=10, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=10, weights=distance; total time=   0.3s
# [CV 3/5] END ...............n_neighbors=10, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=10, weights=distance; total time=   0.3s
# [CV 5/5] END ...............n_neighbors=10, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=11, weights=uniform; total time=   0.3s
# [CV 2/5] END ................n_neighbors=11, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=11, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=11, weights=uniform; total time=   0.3s
# [CV 5/5] END ................n_neighbors=11, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=11, weights=distance; total time=   0.3s
# [CV 2/5] END ...............n_neighbors=11, weights=distance; total time=   0.3s
# [CV 3/5] END ...............n_neighbors=11, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=11, weights=distance; total time=   0.3s
# [CV 5/5] END ...............n_neighbors=11, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=12, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=12, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=12, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=12, weights=uniform; total time=   0.3s
# [CV 5/5] END ................n_neighbors=12, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=12, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=12, weights=distance; total time=   0.3s
# [CV 3/5] END ...............n_neighbors=12, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=12, weights=distance; total time=   0.3s
# [CV 5/5] END ...............n_neighbors=12, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=13, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=13, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=13, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=13, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=13, weights=uniform; total time=   0.5s
# [CV 1/5] END ...............n_neighbors=13, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=13, weights=distance; total time=   0.3s
# [CV 3/5] END ...............n_neighbors=13, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=13, weights=distance; total time=   0.3s
# [CV 5/5] END ...............n_neighbors=13, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=14, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=14, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=14, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=14, weights=uniform; total time=   0.3s
# [CV 5/5] END ................n_neighbors=14, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=14, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=14, weights=distance; total time=   0.3s
# [CV 3/5] END ...............n_neighbors=14, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=14, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=14, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=15, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=15, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=15, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=15, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=15, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=15, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=15, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=15, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=15, weights=distance; total time=   0.3s
# [CV 5/5] END ...............n_neighbors=15, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=16, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=16, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=16, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=16, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=16, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=16, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=16, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=16, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=16, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=16, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=17, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=17, weights=uniform; total time=   0.3s
# [CV 3/5] END ................n_neighbors=17, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=17, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=17, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=17, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=17, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=17, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=17, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=17, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=18, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=18, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=18, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=18, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=18, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=18, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=18, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=18, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=18, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=18, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=19, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=19, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=19, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=19, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=19, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=19, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=19, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=19, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=19, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=19, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=20, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=20, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=20, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=20, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=20, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=20, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=20, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=20, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=20, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=20, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=21, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=21, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=21, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=21, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=21, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=21, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=21, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=21, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=21, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=21, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=22, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=22, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=22, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=22, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=22, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=22, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=22, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=22, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=22, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=22, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=23, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=23, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=23, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=23, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=23, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=23, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=23, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=23, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=23, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=23, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=24, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=24, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=24, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=24, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=24, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=24, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=24, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=24, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=24, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=24, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=25, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=25, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=25, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=25, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=25, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=25, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=25, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=25, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=25, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=25, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=26, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=26, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=26, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=26, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=26, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=26, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=26, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=26, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=26, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=26, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=27, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=27, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=27, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=27, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=27, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=27, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=27, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=27, weights=distance; total time=   0.3s
# [CV 4/5] END ...............n_neighbors=27, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=27, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=28, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=28, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=28, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=28, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=28, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=28, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=28, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=28, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=28, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=28, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=29, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=29, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=29, weights=uniform; total time=   0.3s
# [CV 4/5] END ................n_neighbors=29, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=29, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=29, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=29, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=29, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=29, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=29, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=30, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=30, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=30, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=30, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=30, weights=uniform; total time=   0.3s
# [CV 1/5] END ...............n_neighbors=30, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=30, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=30, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=30, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=30, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=31, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=31, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=31, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=31, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=31, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=31, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=31, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=31, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=31, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=31, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=32, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=32, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=32, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=32, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=32, weights=uniform; total time=   0.5s
# [CV 1/5] END ...............n_neighbors=32, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=32, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=32, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=32, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=32, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=33, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=33, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=33, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=33, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=33, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=33, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=33, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=33, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=33, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=33, weights=distance; total time=   0.3s
# [CV 1/5] END ................n_neighbors=34, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=34, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=34, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=34, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=34, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=34, weights=distance; total time=   0.4s
# [CV 2/5] END ...............n_neighbors=34, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=34, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=34, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=34, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=35, weights=uniform; total time=   0.4s
# [CV 2/5] END ................n_neighbors=35, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=35, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=35, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=35, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=35, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=35, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=35, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=35, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=35, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=36, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=36, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=36, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=36, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=36, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=36, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=36, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=36, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=36, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=36, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=37, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=37, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=37, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=37, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=37, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=37, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=37, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=37, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=37, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=37, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=38, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=38, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=38, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=38, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=38, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=38, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=38, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=38, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=38, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=38, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=39, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=39, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=39, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=39, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=39, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=39, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=39, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=39, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=39, weights=distance; total time=   0.7s
# [CV 5/5] END ...............n_neighbors=39, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=40, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=40, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=40, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=40, weights=uniform; total time=   0.4s
# [CV 5/5] END ................n_neighbors=40, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=40, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=40, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=40, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=40, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=40, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=41, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=41, weights=uniform; total time=   0.6s
# [CV 3/5] END ................n_neighbors=41, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=41, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=41, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=41, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=41, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=41, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=41, weights=distance; total time=   0.4s
# [CV 5/5] END ...............n_neighbors=41, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=42, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=42, weights=uniform; total time=   0.6s
# [CV 3/5] END ................n_neighbors=42, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=42, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=42, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=42, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=42, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=42, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=42, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=42, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=43, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=43, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=43, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=43, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=43, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=43, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=43, weights=distance; total time=   0.4s
# [CV 3/5] END ...............n_neighbors=43, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=43, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=43, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=44, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=44, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=44, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=44, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=44, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=44, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=44, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=44, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=44, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=44, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=45, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=45, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=45, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=45, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=45, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=45, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=45, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=45, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=45, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=45, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=46, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=46, weights=uniform; total time=   0.4s
# [CV 3/5] END ................n_neighbors=46, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=46, weights=uniform; total time=   0.6s
# [CV 5/5] END ................n_neighbors=46, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=46, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=46, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=46, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=46, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=46, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=47, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=47, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=47, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=47, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=47, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=47, weights=distance; total time=   0.6s
# [CV 2/5] END ...............n_neighbors=47, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=47, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=47, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=47, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=48, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=48, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=48, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=48, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=48, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=48, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=48, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=48, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=48, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=48, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=49, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=49, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=49, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=49, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=49, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=49, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=49, weights=distance; total time=   0.6s
# [CV 3/5] END ...............n_neighbors=49, weights=distance; total time=   0.5s
# [CV 4/5] END ...............n_neighbors=49, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=49, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=50, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=50, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=50, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=50, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=50, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=50, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=50, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=50, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=50, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=50, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=51, weights=uniform; total time=   0.6s
# [CV 2/5] END ................n_neighbors=51, weights=uniform; total time=   0.6s
# [CV 3/5] END ................n_neighbors=51, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=51, weights=uniform; total time=   0.6s
# [CV 5/5] END ................n_neighbors=51, weights=uniform; total time=   0.5s
# [CV 1/5] END ...............n_neighbors=51, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=51, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=51, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=51, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=51, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=52, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=52, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=52, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=52, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=52, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=52, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=52, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=52, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=52, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=52, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=53, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=53, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=53, weights=uniform; total time=   0.6s
# [CV 4/5] END ................n_neighbors=53, weights=uniform; total time=   0.6s
# [CV 5/5] END ................n_neighbors=53, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=53, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=53, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=53, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=53, weights=distance; total time=   0.6s
# [CV 5/5] END ...............n_neighbors=53, weights=distance; total time=   0.5s
# [CV 1/5] END ................n_neighbors=54, weights=uniform; total time=   0.7s
# [CV 2/5] END ................n_neighbors=54, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=54, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=54, weights=uniform; total time=   0.8s
# [CV 5/5] END ................n_neighbors=54, weights=uniform; total time=   0.5s
# [CV 1/5] END ...............n_neighbors=54, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=54, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=54, weights=distance; total time=   0.5s
# [CV 4/5] END ...............n_neighbors=54, weights=distance; total time=   0.6s
# [CV 5/5] END ...............n_neighbors=54, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=55, weights=uniform; total time=   0.6s
# [CV 2/5] END ................n_neighbors=55, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=55, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=55, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=55, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=55, weights=distance; total time=   0.6s
# [CV 2/5] END ...............n_neighbors=55, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=55, weights=distance; total time=   0.5s
# [CV 4/5] END ...............n_neighbors=55, weights=distance; total time=   0.7s
# [CV 5/5] END ...............n_neighbors=55, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=56, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=56, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=56, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=56, weights=uniform; total time=   0.6s
# [CV 5/5] END ................n_neighbors=56, weights=uniform; total time=   0.5s
# [CV 1/5] END ...............n_neighbors=56, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=56, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=56, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=56, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=56, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=57, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=57, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=57, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=57, weights=uniform; total time=   0.6s
# [CV 5/5] END ................n_neighbors=57, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=57, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=57, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=57, weights=distance; total time=   0.4s
# [CV 4/5] END ...............n_neighbors=57, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=57, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=58, weights=uniform; total time=   0.5s
# [CV 2/5] END ................n_neighbors=58, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=58, weights=uniform; total time=   0.4s
# [CV 4/5] END ................n_neighbors=58, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=58, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=58, weights=distance; total time=   0.6s
# [CV 2/5] END ...............n_neighbors=58, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=58, weights=distance; total time=   0.5s
# [CV 4/5] END ...............n_neighbors=58, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=58, weights=distance; total time=   0.5s
# [CV 1/5] END ................n_neighbors=59, weights=uniform; total time=   0.6s
# [CV 2/5] END ................n_neighbors=59, weights=uniform; total time=   0.5s
# [CV 3/5] END ................n_neighbors=59, weights=uniform; total time=   0.5s
# [CV 4/5] END ................n_neighbors=59, weights=uniform; total time=   0.5s
# [CV 5/5] END ................n_neighbors=59, weights=uniform; total time=   0.4s
# [CV 1/5] END ...............n_neighbors=59, weights=distance; total time=   0.5s
# [CV 2/5] END ...............n_neighbors=59, weights=distance; total time=   0.5s
# [CV 3/5] END ...............n_neighbors=59, weights=distance; total time=   0.5s
# [CV 4/5] END ...............n_neighbors=59, weights=distance; total time=   0.5s
# [CV 5/5] END ...............n_neighbors=59, weights=distance; total time=   0.4s
# [CV 1/5] END ................n_neighbors=60, weights=uniform; total time=   0.6s
# ...
# [CV 5/5] END ...............n_neighbors=331, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=331, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=331, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=331, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=331, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=331, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=332, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=332, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=332, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=332, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=332, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=332, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=332, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=332, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=332, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=332, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=333, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=333, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=333, weights=uniform; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=333, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=333, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=333, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=333, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=333, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=333, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=333, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=334, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=334, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=334, weights=uniform; total time=   1.0s
# [CV 4/5] END ...............n_neighbors=334, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=334, weights=uniform; total time=   1.0s
# [CV 1/5] END ..............n_neighbors=334, weights=distance; total time=   1.5s
# [CV 2/5] END ..............n_neighbors=334, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=334, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=334, weights=distance; total time=   1.7s
# [CV 5/5] END ..............n_neighbors=334, weights=distance; total time=   1.1s
# [CV 1/5] END ...............n_neighbors=335, weights=uniform; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=335, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=335, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=335, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=335, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=335, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=335, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=335, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=335, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=335, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=336, weights=uniform; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=336, weights=uniform; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=336, weights=uniform; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=336, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=336, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=336, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=336, weights=distance; total time=   1.2s
# [CV 3/5] END ..............n_neighbors=336, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=336, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=336, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=337, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=337, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=337, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=337, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=337, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=337, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=337, weights=distance; total time=   1.2s
# [CV 3/5] END ..............n_neighbors=337, weights=distance; total time=   1.2s
# [CV 4/5] END ..............n_neighbors=337, weights=distance; total time=   1.3s
# [CV 5/5] END ..............n_neighbors=337, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=338, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=338, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=338, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=338, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=338, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=338, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=338, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=338, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=338, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=338, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=339, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=339, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=339, weights=uniform; total time=   1.2s
# [CV 4/5] END ...............n_neighbors=339, weights=uniform; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=339, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=339, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=339, weights=distance; total time=   1.2s
# [CV 3/5] END ..............n_neighbors=339, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=339, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=339, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=340, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=340, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=340, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=340, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=340, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=340, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=340, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=340, weights=distance; total time=   1.2s
# [CV 4/5] END ..............n_neighbors=340, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=340, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=341, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=341, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=341, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=341, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=341, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=341, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=341, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=341, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=341, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=341, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=342, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=342, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=342, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=342, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=342, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=342, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=342, weights=distance; total time=   1.2s
# [CV 3/5] END ..............n_neighbors=342, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=342, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=342, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=343, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=343, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=343, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=343, weights=uniform; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=343, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=343, weights=distance; total time=   1.3s
# [CV 2/5] END ..............n_neighbors=343, weights=distance; total time=   1.3s
# [CV 3/5] END ..............n_neighbors=343, weights=distance; total time=   1.4s
# [CV 4/5] END ..............n_neighbors=343, weights=distance; total time=   1.4s
# [CV 5/5] END ..............n_neighbors=343, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=344, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=344, weights=uniform; total time=   1.4s
# [CV 3/5] END ...............n_neighbors=344, weights=uniform; total time=   1.3s
# [CV 4/5] END ...............n_neighbors=344, weights=uniform; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=344, weights=uniform; total time=   1.1s
# [CV 1/5] END ..............n_neighbors=344, weights=distance; total time=   1.3s
# [CV 2/5] END ..............n_neighbors=344, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=344, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=344, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=344, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=345, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=345, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=345, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=345, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=345, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=345, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=345, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=345, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=345, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=345, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=346, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=346, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=346, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=346, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=346, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=346, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=346, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=346, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=346, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=346, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=347, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=347, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=347, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=347, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=347, weights=uniform; total time=   1.0s
# [CV 1/5] END ..............n_neighbors=347, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=347, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=347, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=347, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=347, weights=distance; total time=   0.9s
# [CV 1/5] END ...............n_neighbors=348, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=348, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=348, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=348, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=348, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=348, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=348, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=348, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=348, weights=distance; total time=   1.3s
# [CV 5/5] END ..............n_neighbors=348, weights=distance; total time=   1.0s
# [CV 1/5] END ...............n_neighbors=349, weights=uniform; total time=   1.2s
# [CV 2/5] END ...............n_neighbors=349, weights=uniform; total time=   1.1s
# [CV 3/5] END ...............n_neighbors=349, weights=uniform; total time=   1.1s
# [CV 4/5] END ...............n_neighbors=349, weights=uniform; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=349, weights=uniform; total time=   0.9s
# [CV 1/5] END ..............n_neighbors=349, weights=distance; total time=   1.2s
# [CV 2/5] END ..............n_neighbors=349, weights=distance; total time=   1.1s
# [CV 3/5] END ..............n_neighbors=349, weights=distance; total time=   1.1s
# [CV 4/5] END ..............n_neighbors=349, weights=distance; total time=   1.2s
# [CV 5/5] END ..............n_neighbors=349, weights=distance; total time=   0.9s
#     param_n_neighbors param_weights  mean_test_score  rank_test_score
# 697               349      distance         0.072941                1
# 695               348      distance         0.072895                2
# 693               347      distance         0.072812                3
# 691               346      distance         0.072739                4
# 689               345      distance         0.072727                5
# ..                ...           ...              ...              ...
# 5                   3      distance        -0.338772              694
# 3                   2      distance        -0.408425              695
# 2                   2       uniform        -0.409302              696
# 1                   1      distance        -0.442528              697
# 0                   1       uniform        -0.442528              697
#
# [698 rows x 4 columns]

# %%
KNNuniform = KNN_results[(KNN_results['param_weights'] == 'uniform' )].sort_values(by = ['param_n_neighbors'])
KNNdistance = KNN_results[(KNN_results['param_weights'] == 'distance' )].sort_values(by = ['param_n_neighbors'])

plt.plot(KNNuniform['param_n_neighbors'], KNNuniform['mean_test_score'], label = 'uniform')
plt.plot(KNNdistance['param_n_neighbors'], KNNdistance['mean_test_score'], label = 'distance')

plt.xlabel('Param N Neighbors')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores for different parameter combinations of kNN')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
estimator = KNeighborsRegressor(n_neighbors = 38, weights = 'distance').fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

KNNMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions')
# Display a figure.
plt.show()
# Out:
# 6.928693168907422

# %%
plt.title('KNN predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()

# %% [markdown]
# # SVM Regression

# %%
SVM = GridSearchCV(svm.SVR(gamma='scale'), {
    'C': [0.01, 0.1, 1, 100], 
    'kernel': ['rbf','linear'],
    'epsilon': [0.01,0.1,1,10]
}, cv=5, return_train_score=False, verbose = 4)
SVM.fit(inputXscaled, inputy)

svm_results = pd.DataFrame(SVM.cv_results_)
svmresults = svm_results[['param_kernel','param_C','param_epsilon', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
svmresults
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  30.9s
# [CV 2/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  30.7s
# [CV 3/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  30.5s
# [CV 4/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  31.5s
# [CV 5/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  30.8s
# [CV 1/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  15.6s
# [CV 2/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  15.9s
# [CV 3/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  15.6s
# [CV 4/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  16.0s
# [CV 5/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  15.7s
# [CV 1/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  30.7s
# [CV 2/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.4s
# [CV 3/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.0s
# [CV 4/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  31.2s
# [CV 5/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  30.7s
# [CV 1/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  15.5s
# [CV 2/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  15.8s
# [CV 3/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  15.5s
# [CV 4/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  15.9s
# [CV 5/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  15.6s
# [CV 1/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.4s
# [CV 2/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.4s
# [CV 3/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.5s
# [CV 4/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  30.9s
# [CV 5/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.2s
# [CV 1/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.3s
# [CV 2/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.5s
# [CV 3/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.5s
# [CV 4/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.7s
# [CV 5/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.5s
# [CV 1/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.7s
# [CV 2/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.7s
# [CV 3/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.8s
# [CV 4/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  28.5s
# [CV 5/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=  29.0s
# [CV 1/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  13.9s
# [CV 2/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  14.3s
# [CV 3/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  14.2s
# [CV 4/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  14.7s
# [CV 5/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=  17.1s
# [CV 1/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  30.2s
# [CV 2/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  30.5s
# [CV 3/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  31.3s
# [CV 4/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  30.7s
# [CV 5/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  30.2s
# [CV 1/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  15.9s
# [CV 2/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  15.7s
# [CV 3/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  15.9s
# [CV 4/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  16.3s
# [CV 5/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  15.8s
# [CV 1/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  30.1s
# [CV 2/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  30.4s
# [CV 3/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  30.0s
# [CV 4/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  30.7s
# [CV 5/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  30.0s
# [CV 1/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  15.9s
# [CV 2/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  15.6s
# [CV 3/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  15.7s
# [CV 4/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  16.2s
# [CV 5/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  15.9s
# [CV 1/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  29.8s
# [CV 2/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.0s
# [CV 3/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  29.6s
# [CV 4/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  30.4s
# [CV 5/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  29.7s
# [CV 1/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  15.4s
# [CV 2/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  15.8s
# [CV 3/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  15.5s
# [CV 4/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  15.9s
# [CV 5/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  15.6s
# [CV 1/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  26.8s
# [CV 2/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  27.6s
# [CV 3/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  27.2s
# [CV 4/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  25.8s
# [CV 5/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=  26.6s
# [CV 1/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  13.9s
# [CV 2/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  14.3s
# [CV 3/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  14.1s
# [CV 4/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  14.7s
# [CV 5/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=  14.1s
# [CV 1/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  29.8s
# [CV 2/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  30.1s
# [CV 3/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  30.2s
# [CV 4/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  30.8s
# [CV 5/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  30.2s
# [CV 1/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  16.1s
# [CV 2/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  16.0s
# [CV 3/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  16.0s
# [CV 4/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  16.8s
# [CV 5/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  16.2s
# [CV 1/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  29.8s
# [CV 2/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  30.3s
# [CV 3/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  29.9s
# [CV 4/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  30.7s
# [CV 5/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  29.9s
# [CV 1/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  16.2s
# [CV 2/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  16.0s
# [CV 3/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  16.0s
# [CV 4/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  16.4s
# [CV 5/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  16.4s
# [CV 1/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.1s
# [CV 2/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.6s
# [CV 3/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.3s
# [CV 4/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  30.3s
# [CV 5/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  29.4s
# [CV 1/5] END ..................C=1, epsilon=1, kernel=linear; total time=  15.6s
# [CV 2/5] END ..................C=1, epsilon=1, kernel=linear; total time=  16.0s
# [CV 3/5] END ..................C=1, epsilon=1, kernel=linear; total time=  15.8s
# [CV 4/5] END ..................C=1, epsilon=1, kernel=linear; total time=  16.2s
# [CV 5/5] END ..................C=1, epsilon=1, kernel=linear; total time=  15.8s
# [CV 1/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  25.7s
# [CV 2/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  25.0s
# [CV 3/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  24.3s
# [CV 4/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  22.5s
# [CV 5/5] END ....................C=1, epsilon=10, kernel=rbf; total time=  23.6s
# [CV 1/5] END .................C=1, epsilon=10, kernel=linear; total time=  14.4s
# [CV 2/5] END .................C=1, epsilon=10, kernel=linear; total time=  14.5s
# [CV 3/5] END .................C=1, epsilon=10, kernel=linear; total time=  14.3s
# [CV 4/5] END .................C=1, epsilon=10, kernel=linear; total time=  14.2s
# [CV 5/5] END .................C=1, epsilon=10, kernel=linear; total time=  14.5s
# [CV 1/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  32.2s
# [CV 2/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  32.0s
# [CV 3/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  32.1s
# [CV 4/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  33.9s
# [CV 5/5] END ................C=100, epsilon=0.01, kernel=rbf; total time=  32.5s
# [CV 1/5] END .............C=100, epsilon=0.01, kernel=linear; total time=  29.2s
# [CV 2/5] END .............C=100, epsilon=0.01, kernel=linear; total time=  28.7s
# [CV 3/5] END .............C=100, epsilon=0.01, kernel=linear; total time=  27.0s
# [CV 4/5] END .............C=100, epsilon=0.01, kernel=linear; total time=  31.9s
# [CV 5/5] END .............C=100, epsilon=0.01, kernel=linear; total time=  31.5s
# [CV 1/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  32.0s
# [CV 2/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  31.9s
# [CV 3/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  32.4s
# [CV 4/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  33.8s
# [CV 5/5] END .................C=100, epsilon=0.1, kernel=rbf; total time=  32.5s
# [CV 1/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=  27.9s
# [CV 2/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=  28.0s
# [CV 3/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=  26.6s
# [CV 4/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=  31.6s
# [CV 5/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=  30.9s
# [CV 1/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  30.9s
# [CV 2/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  30.7s
# [CV 3/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  31.2s
# [CV 4/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  32.0s
# [CV 5/5] END ...................C=100, epsilon=1, kernel=rbf; total time=  31.4s
# [CV 1/5] END ................C=100, epsilon=1, kernel=linear; total time=  28.1s
# [CV 2/5] END ................C=100, epsilon=1, kernel=linear; total time=  27.8s
# [CV 3/5] END ................C=100, epsilon=1, kernel=linear; total time=  27.3s
# [CV 4/5] END ................C=100, epsilon=1, kernel=linear; total time=  32.2s
# [CV 5/5] END ................C=100, epsilon=1, kernel=linear; total time=  30.4s
# [CV 1/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  22.5s
# [CV 2/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  23.5s
# [CV 3/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  22.9s
# [CV 4/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  21.4s
# [CV 5/5] END ..................C=100, epsilon=10, kernel=rbf; total time=  24.5s
# [CV 1/5] END ...............C=100, epsilon=10, kernel=linear; total time=  26.1s
# [CV 2/5] END ...............C=100, epsilon=10, kernel=linear; total time=  25.6s
# [CV 3/5] END ...............C=100, epsilon=10, kernel=linear; total time=  24.8s
# [CV 4/5] END ...............C=100, epsilon=10, kernel=linear; total time=  28.1s
# [CV 5/5] END ...............C=100, epsilon=10, kernel=linear; total time=  26.6s
#    param_kernel param_C param_epsilon  mean_test_score  rank_test_score
# 14          rbf     0.1            10        -0.068579                1
# 10          rbf     0.1           0.1        -0.082311                2
# 8           rbf     0.1          0.01        -0.082440                3
# 12          rbf     0.1             1        -0.082694                4
# 7        linear    0.01            10        -0.085135                5
# 5        linear    0.01             1        -0.100354                6
# 1        linear    0.01          0.01        -0.100629                7
# 3        linear    0.01           0.1        -0.100796                8
# 22          rbf       1            10        -0.123696                9
# 18          rbf       1           0.1        -0.146614               10
# 16          rbf       1          0.01        -0.146812               11
# 20          rbf       1             1        -0.149461               12
# 15       linear     0.1            10        -0.198000               13
# 13       linear     0.1             1        -0.203552               14
# 11       linear     0.1           0.1        -0.203777               15
# 9        linear     0.1          0.01        -0.203967               16
# 23       linear       1            10        -0.248624               17
# 21       linear       1             1        -0.252148               18
# 17       linear       1          0.01        -0.253184               19
# 19       linear       1           0.1        -0.253914               20
# 31       linear     100            10        -0.261859               21
# 27       linear     100           0.1        -0.265739               22
# 25       linear     100          0.01        -0.265860               23
# 29       linear     100             1        -0.266097               24
# 6           rbf    0.01            10        -0.292619               25
# 0           rbf    0.01          0.01        -0.316884               26
# 2           rbf    0.01           0.1        -0.316886               27
# 4           rbf    0.01             1        -0.317294               28
# 24          rbf     100          0.01        -0.475870               29
# 26          rbf     100           0.1        -0.477481               30
# 28          rbf     100             1        -0.487527               31
# 30          rbf     100            10        -0.512966               32

# %%
#from sklearn.model_selection import train_test_split

#X_train,X_test,y_train,y_test = train_test_split(X1scaled,y1,test_size=0.25,random_state=42) #split training:testing 75:25


estimator = svm.SVR(C = 0.1,  kernel = 'rbf', epsilon = 10).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions')
# Display a figure.
plt.show()
# Out:
# 10.639239156781656

# %%
pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(SVMMAPE)

plt.title('SVM predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 10.129668489226514

# %% [markdown]
# # Multilayer perceptron

# %%
from sklearn.neural_network import MLPRegressor

layers = range(1,30)

parameters = {'hidden_layer_sizes': layers, 'solver': ['lbfgs', 'adam'], 'max_iter': [4000], 'learning_rate_init': 10.0 ** -np.arange(1, 6, 2), 'random_state':[42]}
MLPReg = GridSearchCV(MLPRegressor(), parameters, cv=5,  verbose=2, return_train_score=False)
MLPReg.fit(inputXscaled, inputy)

MLPRegRes = pd.DataFrame(MLPReg.cv_results_)
MLP_results = MLPRegRes[['rank_test_score', 'mean_test_score', 'param_hidden_layer_sizes', 'param_solver', 'param_max_iter', 'param_learning_rate_init']].sort_values(by=['rank_test_score'])
MLP_results
# Out:
# Fitting 5 folds for each of 174 candidates, totalling 870 fits
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   3.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=   6.8s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=   8.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  19.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=   8.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.6min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   4.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  11.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  11.1s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  23.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.1min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  14.7s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.7s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.9s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.7s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  18.3s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  18.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  18.3s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  20.7s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.0s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   3.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.0s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  43.6s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  17.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.4min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.2min
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  25.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   7.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.0s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.1s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.1s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.3s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  15.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  22.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  31.0s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  27.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  21.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.5s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  33.9s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  32.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  30.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  34.9s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.1min
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   7.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  20.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  11.7s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   5.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   7.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  18.7s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  12.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   5.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  23.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  26.5s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  29.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.1min
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  19.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   8.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  18.8s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  11.7s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   1.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   5.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.8min
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  19.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.7s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  18.5s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=   5.1s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  17.2s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  19.8s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  53.7s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  32.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  35.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  19.1s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   3.7s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=   4.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 1.9min
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  10.7s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  14.8s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=   6.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  51.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  49.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  51.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=28, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  54.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  53.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.6s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   6.4s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   2.1s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   5.0s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=4000, random_state=42, solver=adam; total time=   4.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  51.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  55.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.3s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.5min
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  33.4s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  38.6s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time= 1.2min
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=4000, random_state=42, solver=adam; total time=  51.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  53.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  52.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  54.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  55.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=lbfgs; total time=  53.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=4000, random_state=42, solver=adam; total time= 2.7min
#     rank_test_score  mean_test_score param_hidden_layer_sizes param_solver  \
# 39                1        -0.029361                        7         adam
# 14                2        -0.074800                        3        lbfgs
# 12                2        -0.074800                        3        lbfgs
# 16                2        -0.074800                        3        lbfgs
# 69                5        -0.085144                       12         adam
# ..              ...              ...                      ...          ...
# 23              170       -12.781597                        4         adam
# 17              171       -15.542345                        3         adam
# 29              172       -15.983685                        5         adam
# 11              173       -17.803554                        2         adam
# 5               174       -19.463791                        1         adam
#
#    param_max_iter param_learning_rate_init
# 39           4000                    0.001
# 14           4000                    0.001
# 12           4000                      0.1
# 16           4000                  0.00001
# 69           4000                    0.001
# ..            ...                      ...
# 23           4000                  0.00001
# 17           4000                  0.00001
# 29           4000                  0.00001
# 11           4000                  0.00001
# 5            4000                  0.00001
#
# [174 rows x 6 columns]

# %%
estimator = MLPRegressor(hidden_layer_sizes=7, solver = 'adam', max_iter=4000, learning_rate_init=0.001, random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions')
# Display a figure.
plt.show()
# Out:
# 10.129668489226514

# %%
pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(MLPMAPE)

plt.title('Multi Layer Perceptron predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 15.75648422880426

# %% [markdown]
# # Random Split

# %%
df = pd.read_excel("BaseFeaturesHH.xlsx")
df = df.drop('Unnamed: 0', axis = 1)

lagNumberStart = 1
lagNumberEnd = 8

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    df[name] = df['HH Electricity (kWh)'].shift(48*i)

i = list(range(lagNumberEnd*48))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting
Y = df[['HH Electricity (kWh)']]


scaler = StandardScaler() #scaling
scaler.fit(X)
Xscaled = scaler.transform(X)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Xscaled,Y,test_size=0.20,random_state=42) #split training:testing 80:20

# %%
estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(X_train, ravel(y_train))
y_pred = estimator.predict(X_test)

RandomForestMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()
# Out:
# <ipython-input-180-ed12b10fd0af>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(X_train, y_train)
# 5.301960797789791

# %%
estimator = KNeighborsRegressor(n_neighbors = 104, weights = 'distance').fit(X_train, y_train)
y_pred = estimator.predict(X_test)

KNNMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions')
# Display a figure.
plt.show()
# Out:
# 7.654330433078378

# %%
estimator = svm.SVR(C = 1,  kernel = 'rbf', epsilon = 0.1).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

SVMMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 7.325068194913794

# %%
from sklearn.neural_network import MLPRegressor

layers = range(1,30)

parameters = {'hidden_layer_sizes': layers, 'solver': ['lbfgs', 'adam'], 'max_iter': [2500], 'learning_rate_init': 10.0 ** -np.arange(1, 6, 2), 'random_state':[42]}
MLPReg = GridSearchCV(MLPRegressor(), parameters, cv=5,  verbose=2, return_train_score=False)
MLPReg.fit(X_train, y_train)

MLPRegRes = pd.DataFrame(MLPReg.cv_results_)
MLP_results = MLPRegRes[['rank_test_score', 'mean_test_score', 'param_hidden_layer_sizes', 'param_solver', 'param_max_iter', 'param_learning_rate_init']].sort_values(by=['rank_test_score'])
MLP_results
# Out:
# Fitting 5 folds for each of 174 candidates, totalling 870 fits
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   9.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.2min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  16.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  15.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  26.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   7.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  17.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  27.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   7.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   3.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  49.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.3s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  23.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  28.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  21.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#      rank_test_score  mean_test_score param_hidden_layer_sizes param_solver  \
# 172                1         0.901754                       29        lbfgs
# 170                1         0.901754                       29        lbfgs
# 168                1         0.901754                       29        lbfgs
# 124                4         0.899988                       21        lbfgs
# 122                4         0.899988                       21        lbfgs
# ..               ...              ...                      ...          ...
# 23               170         0.653448                        4         adam
# 41               171         0.618623                        7         adam
# 3                172        -0.000212                        1         adam
# 11               173        -2.319447                        2         adam
# 5                174        -7.063683                        1         adam
#
#     param_max_iter param_learning_rate_init
# 172           2500                  0.00001
# 170           2500                    0.001
# 168           2500                      0.1
# 124           2500                  0.00001
# 122           2500                    0.001
# ..             ...                      ...
# 23            2500                  0.00001
# 41            2500                  0.00001
# 3             2500                    0.001
# 11            2500                  0.00001
# 5             2500                  0.00001
#
# [174 rows x 6 columns]

# %%
estimator = MLPRegressor(hidden_layer_sizes=5, solver = 'lbfgs', max_iter=3000, learning_rate_init=0.1, random_state=42).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

MLPMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 8.597355117603344
