# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Redoing model selection with validation set

# %%
df = pd.read_excel("BaseFeaturesHH.xlsx")
df = df.drop('Unnamed: 0', axis = 1)
df
# Out:
#            From Timestamp  HH Electricity (kWh)  dayofweek  hour  holiday  \
# 0     2018-01-01 00:00:00                 12.80          0   0.0        1
# 1     2018-01-01 00:30:00                 12.30          0   0.5        1
# 2     2018-01-01 01:00:00                 13.50          0   1.0        1
# 3     2018-01-01 01:30:00                 11.90          0   1.5        1
# 4     2018-01-01 02:00:00                 12.80          0   2.0        1
# ...                   ...                   ...        ...   ...      ...
# 35035 2019-12-31 21:30:00                 13.56          1  21.5        0
# 35036 2019-12-31 22:00:00                 13.81          1  22.0        0
# 35037 2019-12-31 22:30:00                 14.12          1  22.5        0
# 35038 2019-12-31 23:00:00                 14.50          1  23.0        0
# 35039 2019-12-31 23:30:00                 13.88          1  23.5        0
#
#        month  Temperature (C)  Feels like (C)  Humidity (%)
# 0          1              6.4             1.9         82.76
# 1          1              6.4             1.9         82.76
# 2          1              6.6             2.4         80.14
# 3          1              6.6             2.4         80.14
# 4          1              6.1             2.0         84.33
# ...      ...              ...             ...           ...
# 35035     12              6.5             3.3         88.23
# 35036     12              6.6             4.4         87.69
# 35037     12              6.6             4.4         87.69
# 35038     12              6.7             4.1         88.13
# 35039     12              6.7             4.1         88.13
#
# [35040 rows x 9 columns]

# %% [markdown]
# # First by splitting it according to time
# The splitting will be 60:20:20

# %%
lagNumberStart = 1
lagNumberEnd = 8

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    df[name] = df['HH Electricity (kWh)'].shift(48*i)

i = list(range(lagNumberEnd*48))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting

size = -int(len(df)*0.2)

Xinput = df.iloc[:size]
Xtest = df.iloc[size:] # 20%

size2 = -int(len(Xinput)*0.25)

Xtrain = Xinput.iloc[:size2].copy() #60%
Xvalidate = Xinput.iloc[size2:].copy() #20%

trainX = Xtrain[feature_cols] # Features
trainy = Xtrain['HH Electricity (kWh)'] # Target variable

validateX = Xvalidate[feature_cols] # Features
validatey = Xvalidate['HH Electricity (kWh)'] # Target variable

testX = Xtest[feature_cols] # Features
testy = Xtest['HH Electricity (kWh)'] # Target variable

inputX = Xinput[feature_cols] # Features
inputy = Xinput['HH Electricity (kWh)'] # Target variable

scaler = StandardScaler() #scaling
scaler.fit(X)
trainXscaled = scaler.transform(trainX)
validateXscaled = scaler.transform(validateX)
testXscaled = scaler.transform(testX)
inputXscaled = scaler.transform(inputX)

# %%
print(len(trainXscaled))
print(len(validateXscaled))
print(len(testXscaled))
print(len(inputXscaled))
# Out:
# 20794
# 6931
# 6931
# 27725

# %% [markdown]
# # Random Forest Regressor

# %%
N = range(10,1011,100)

RFR = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR.fit(inputXscaled, inputy)

RFR_results = pd.DataFrame(RFR.cv_results_)
RFR_results = RFR_results[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFR_results
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 8                 810         0.838345                1
# 9                 910         0.838318                2
# 10               1010         0.838296                3
# 7                 710         0.838296                4
# 5                 510         0.838185                5
# 6                 610         0.838130                6
# 3                 310         0.837958                7
# 4                 410         0.837854                8
# 1                 110         0.837504                9
# 2                 210         0.837359               10
# 0                  10         0.827311               11

# %%
N = range(5,96,10)

RFR1 = GridSearchCV(RandomForestRegressor(random_state=42), {
    'n_estimators': N
}, cv=5, return_train_score=False)
RFR1.fit(inputXscaled, inputy)

RFRresults1 = pd.DataFrame(RFR1.cv_results_)
RFRresults1 = RFRresults1[['param_n_estimators', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
RFRresults1
# Out:
#   param_n_estimators  mean_test_score  rank_test_score
# 9                 95         0.837949                1
# 8                 85         0.837701                2
# 7                 75         0.837543                3
# 5                 55         0.837162                4
# 6                 65         0.837142                5
# 3                 35         0.836777                6
# 4                 45         0.836658                7
# 2                 25         0.835001                8
# 1                 15         0.833903                9
# 0                  5         0.812519               10

# %%
RFRresults2 = RFR_results.copy()
RFRresults = RFRresults2.append(RFRresults1)
RFRresults = RFRresults.sort_values(by=['mean_test_score'])
RFRresults
# Out:
#    param_n_estimators  mean_test_score  rank_test_score
# 0                   5         0.812519               10
# 0                  10         0.827311               11
# 1                  15         0.833903                9
# 2                  25         0.835001                8
# 3                  35         0.836777                6
# 4                  45         0.836658                7
# 5                  55         0.837162                4
# 6                  65         0.837142                5
# 7                  75         0.837543                3
# 8                  85         0.837701                2
# 9                  95         0.837949                1
# 1                 110         0.837504                9
# 2                 210         0.837359               10
# 3                 310         0.837958                7
# 4                 410         0.837854                8
# 5                 510         0.838185                5
# 6                 610         0.838130                6
# 7                 710         0.838296                4
# 8                 810         0.838345                1
# 9                 910         0.838318                2
# 10               1010         0.838296                3

# %%
RFRresults = RFRresults.sort_values(by=['param_n_estimators'])
plt.plot(RFRresults['param_n_estimators'], RFRresults['mean_test_score'])

plt.xlabel('Number of Trees')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores of different number of trees for Random Forest')
# Display a figure.
plt.show()

# %%
estimator = RandomForestRegressor(n_estimators = 800,  random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()
# Out:
# 9.355486354702085

# %%
pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(RandomForestMAPE)

plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 9.355486354702085

# %% [markdown]
# # Visualization examples

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+4350], df['From Timestamp'].iloc[size+5400])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+4914], df['From Timestamp'].iloc[size+4964])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# Looks decent but on other parts:

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+5400], df['From Timestamp'].iloc[size+6500])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# This should be the worst part

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+1400], df['From Timestamp'].iloc[size+2500])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# what is that random spike during the weekend between the 2nd and 3rd week

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.plot(df['From Timestamp'].iloc[size:],df['Feels like (C)'].iloc[size:], label = "Feels like (C)")
plt.xlim(df['From Timestamp'].iloc[size+1800], df['From Timestamp'].iloc[size+2100])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# ### Unless we consider "International Talk like a Pirate Day" to be a special day there is no information/data that would justify the unusual behaviour on that day

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.plot(df['From Timestamp'].iloc[size:],df['Feels like (C)'].iloc[size:], label = "Feels like (C)")
plt.xlim(df['From Timestamp'].iloc[size+1200], df['From Timestamp'].iloc[size+1700])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # With the code below we search for interesting points to analyse with SHAP in the jupyter notebook 2.3

# %%
plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.plot(df['From Timestamp'].iloc[size:],df['Feels like (C)'].iloc[size:], label = "Feels like (C)")
plt.xlim(df['From Timestamp'].iloc[size+5500], df['From Timestamp'].iloc[size+6500])
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # Interesting to note the last week: First Spike underestimated but then it catches up.

# %%
error = 100*(pred - testy)/testy
plt.hist(error, bins=100)
plt.title('Distribution of Random Forest Regressor prediction errors')
plt.xlabel('Prediction Error in %')
_ = plt.ylabel('Count')

# %% [markdown]
# ## When experimenting with the visualization I found an interesting point. It seems like the data is still not *clean*

# %%
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
plt.xlim(df['From Timestamp'].iloc[size+3750], df['From Timestamp'].iloc[size+3780])
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.xticks(rotation=45)
# show a legend on the plot
plt.legend()

# %% [markdown]
# # KNN

# %%
N = range(1,150,1)

KNN = GridSearchCV(KNeighborsRegressor(), {
    'n_neighbors': N,
    'weights': ['uniform', 'distance']
}, cv=5, return_train_score=False, verbose = 3)
KNN.fit(inputXscaled, inputy)
KNN_results = pd.DataFrame(KNN.cv_results_)
KNN_results = KNN_results[['param_n_neighbors', 'param_weights', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
KNN_results
# Out:
# Fitting 5 folds for each of 298 candidates, totalling 1490 fits
# [CV 1/5] END .................n_neighbors=1, weights=uniform; total time=   1.3s
# [CV 2/5] END .................n_neighbors=1, weights=uniform; total time=   1.6s
# [CV 3/5] END .................n_neighbors=1, weights=uniform; total time=   1.2s
# [CV 4/5] END .................n_neighbors=1, weights=uniform; total time=   1.0s
# [CV 5/5] END .................n_neighbors=1, weights=uniform; total time=   1.0s
# [CV 1/5] END ................n_neighbors=1, weights=distance; total time=   1.3s
# [CV 2/5] END ................n_neighbors=1, weights=distance; total time=   1.5s
# [CV 3/5] END ................n_neighbors=1, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=1, weights=distance; total time=   1.1s
# [CV 5/5] END ................n_neighbors=1, weights=distance; total time=   1.9s
# [CV 1/5] END .................n_neighbors=2, weights=uniform; total time=   1.5s
# [CV 2/5] END .................n_neighbors=2, weights=uniform; total time=   1.3s
# [CV 3/5] END .................n_neighbors=2, weights=uniform; total time=   1.2s
# [CV 4/5] END .................n_neighbors=2, weights=uniform; total time=   1.0s
# [CV 5/5] END .................n_neighbors=2, weights=uniform; total time=   1.1s
# [CV 1/5] END ................n_neighbors=2, weights=distance; total time=   1.0s
# [CV 2/5] END ................n_neighbors=2, weights=distance; total time=   1.2s
# [CV 3/5] END ................n_neighbors=2, weights=distance; total time=   1.3s
# [CV 4/5] END ................n_neighbors=2, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=2, weights=distance; total time=   1.1s
# [CV 1/5] END .................n_neighbors=3, weights=uniform; total time=   1.1s
# [CV 2/5] END .................n_neighbors=3, weights=uniform; total time=   1.3s
# [CV 3/5] END .................n_neighbors=3, weights=uniform; total time=   1.3s
# [CV 4/5] END .................n_neighbors=3, weights=uniform; total time=   1.1s
# [CV 5/5] END .................n_neighbors=3, weights=uniform; total time=   1.1s
# [CV 1/5] END ................n_neighbors=3, weights=distance; total time=   1.1s
# [CV 2/5] END ................n_neighbors=3, weights=distance; total time=   1.3s
# [CV 3/5] END ................n_neighbors=3, weights=distance; total time=   1.2s
# [CV 4/5] END ................n_neighbors=3, weights=distance; total time=   1.0s
# [CV 5/5] END ................n_neighbors=3, weights=distance; total time=   1.1s
# [CV 1/5] END .................n_neighbors=4, weights=uniform; total time=   1.2s
# [CV 2/5] END .................n_neighbors=4, weights=uniform; total time=   1.6s
# [CV 3/5] END .................n_neighbors=4, weights=uniform; total time=   1.6s
# [CV 4/5] END .................n_neighbors=4, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=4, weights=uniform; total time=   1.2s
# [CV 1/5] END ................n_neighbors=4, weights=distance; total time=   1.5s
# [CV 2/5] END ................n_neighbors=4, weights=distance; total time=   1.4s
# [CV 3/5] END ................n_neighbors=4, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=4, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=4, weights=distance; total time=   1.1s
# [CV 1/5] END .................n_neighbors=5, weights=uniform; total time=   1.2s
# [CV 2/5] END .................n_neighbors=5, weights=uniform; total time=   1.3s
# [CV 3/5] END .................n_neighbors=5, weights=uniform; total time=   1.4s
# [CV 4/5] END .................n_neighbors=5, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=5, weights=uniform; total time=   1.2s
# [CV 1/5] END ................n_neighbors=5, weights=distance; total time=   1.2s
# [CV 2/5] END ................n_neighbors=5, weights=distance; total time=   1.4s
# [CV 3/5] END ................n_neighbors=5, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=5, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=5, weights=distance; total time=   1.1s
# [CV 1/5] END .................n_neighbors=6, weights=uniform; total time=   1.2s
# [CV 2/5] END .................n_neighbors=6, weights=uniform; total time=   1.5s
# [CV 3/5] END .................n_neighbors=6, weights=uniform; total time=   1.4s
# [CV 4/5] END .................n_neighbors=6, weights=uniform; total time=   1.3s
# [CV 5/5] END .................n_neighbors=6, weights=uniform; total time=   1.6s
# [CV 1/5] END ................n_neighbors=6, weights=distance; total time=   1.2s
# [CV 2/5] END ................n_neighbors=6, weights=distance; total time=   1.3s
# [CV 3/5] END ................n_neighbors=6, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=6, weights=distance; total time=   1.1s
# [CV 5/5] END ................n_neighbors=6, weights=distance; total time=   1.2s
# [CV 1/5] END .................n_neighbors=7, weights=uniform; total time=   1.2s
# [CV 2/5] END .................n_neighbors=7, weights=uniform; total time=   1.4s
# [CV 3/5] END .................n_neighbors=7, weights=uniform; total time=   1.7s
# [CV 4/5] END .................n_neighbors=7, weights=uniform; total time=   2.3s
# [CV 5/5] END .................n_neighbors=7, weights=uniform; total time=   1.4s
# [CV 1/5] END ................n_neighbors=7, weights=distance; total time=   1.4s
# [CV 2/5] END ................n_neighbors=7, weights=distance; total time=   1.5s
# [CV 3/5] END ................n_neighbors=7, weights=distance; total time=   1.5s
# [CV 4/5] END ................n_neighbors=7, weights=distance; total time=   1.2s
# [CV 5/5] END ................n_neighbors=7, weights=distance; total time=   1.3s
# [CV 1/5] END .................n_neighbors=8, weights=uniform; total time=   1.3s
# [CV 2/5] END .................n_neighbors=8, weights=uniform; total time=   1.4s
# [CV 3/5] END .................n_neighbors=8, weights=uniform; total time=   1.6s
# [CV 4/5] END .................n_neighbors=8, weights=uniform; total time=   1.7s
# [CV 5/5] END .................n_neighbors=8, weights=uniform; total time=   1.2s
# [CV 1/5] END ................n_neighbors=8, weights=distance; total time=   1.4s
# [CV 2/5] END ................n_neighbors=8, weights=distance; total time=   1.4s
# [CV 3/5] END ................n_neighbors=8, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=8, weights=distance; total time=   1.5s
# [CV 5/5] END ................n_neighbors=8, weights=distance; total time=   1.8s
# [CV 1/5] END .................n_neighbors=9, weights=uniform; total time=   1.4s
# [CV 2/5] END .................n_neighbors=9, weights=uniform; total time=   1.5s
# [CV 3/5] END .................n_neighbors=9, weights=uniform; total time=   1.5s
# [CV 4/5] END .................n_neighbors=9, weights=uniform; total time=   1.2s
# [CV 5/5] END .................n_neighbors=9, weights=uniform; total time=   1.2s
# [CV 1/5] END ................n_neighbors=9, weights=distance; total time=   1.3s
# [CV 2/5] END ................n_neighbors=9, weights=distance; total time=   1.4s
# [CV 3/5] END ................n_neighbors=9, weights=distance; total time=   1.4s
# [CV 4/5] END ................n_neighbors=9, weights=distance; total time=   1.4s
# [CV 5/5] END ................n_neighbors=9, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=10, weights=uniform; total time=   1.2s
# [CV 2/5] END ................n_neighbors=10, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=10, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=10, weights=uniform; total time=   1.2s
# [CV 5/5] END ................n_neighbors=10, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=10, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=10, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=10, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=10, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=10, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=11, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=11, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=11, weights=uniform; total time=   1.4s
# [CV 4/5] END ................n_neighbors=11, weights=uniform; total time=   1.2s
# [CV 5/5] END ................n_neighbors=11, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=11, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=11, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=11, weights=distance; total time=   1.5s
# [CV 4/5] END ...............n_neighbors=11, weights=distance; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=11, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=12, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=12, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=12, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=12, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=12, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=12, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=12, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=12, weights=distance; total time=   1.5s
# [CV 4/5] END ...............n_neighbors=12, weights=distance; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=12, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=13, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=13, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=13, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=13, weights=uniform; total time=   1.2s
# [CV 5/5] END ................n_neighbors=13, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=13, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=13, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=13, weights=distance; total time=   1.5s
# [CV 4/5] END ...............n_neighbors=13, weights=distance; total time=   1.2s
# [CV 5/5] END ...............n_neighbors=13, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=14, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=14, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=14, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=14, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=14, weights=uniform; total time=   1.2s
# [CV 1/5] END ...............n_neighbors=14, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=14, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=14, weights=distance; total time=   1.5s
# [CV 4/5] END ...............n_neighbors=14, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=14, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=15, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=15, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=15, weights=uniform; total time=   1.5s
# [CV 4/5] END ................n_neighbors=15, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=15, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=15, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=15, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=15, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=15, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=15, weights=distance; total time=   1.2s
# [CV 1/5] END ................n_neighbors=16, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=16, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=16, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=16, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=16, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=16, weights=distance; total time=   1.3s
# [CV 2/5] END ...............n_neighbors=16, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=16, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=16, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=16, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=17, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=17, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=17, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=17, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=17, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=17, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=17, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=17, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=17, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=17, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=18, weights=uniform; total time=   1.3s
# [CV 2/5] END ................n_neighbors=18, weights=uniform; total time=   1.5s
# [CV 3/5] END ................n_neighbors=18, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=18, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=18, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=18, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=18, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=18, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=18, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=18, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=19, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=19, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=19, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=19, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=19, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=19, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=19, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=19, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=19, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=19, weights=distance; total time=   1.3s
# [CV 1/5] END ................n_neighbors=20, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=20, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=20, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=20, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=20, weights=uniform; total time=   1.3s
# [CV 1/5] END ...............n_neighbors=20, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=20, weights=distance; total time=   1.5s
# [CV 3/5] END ...............n_neighbors=20, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=20, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=20, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=21, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=21, weights=uniform; total time=   1.7s
# [CV 3/5] END ................n_neighbors=21, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=21, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=21, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=21, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=21, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=21, weights=distance; total time=   1.6s
# [CV 4/5] END ...............n_neighbors=21, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=21, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=22, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=22, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=22, weights=uniform; total time=   1.6s
# [CV 4/5] END ................n_neighbors=22, weights=uniform; total time=   1.3s
# [CV 5/5] END ................n_neighbors=22, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=22, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=22, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=22, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=22, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=22, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=23, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=23, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=23, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=23, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=23, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=23, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=23, weights=distance; total time=   1.6s
# [CV 3/5] END ...............n_neighbors=23, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=23, weights=distance; total time=   1.3s
# [CV 5/5] END ...............n_neighbors=23, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=24, weights=uniform; total time=   1.8s
# [CV 2/5] END ................n_neighbors=24, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=24, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=24, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=24, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=24, weights=distance; total time=   1.4s
# [CV 2/5] END ...............n_neighbors=24, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=24, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=24, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=24, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=25, weights=uniform; total time=   1.4s
# [CV 2/5] END ................n_neighbors=25, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=25, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=25, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=25, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=25, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=25, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=25, weights=distance; total time=   1.7s
# [CV 4/5] END ...............n_neighbors=25, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=25, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=26, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=26, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=26, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=26, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=26, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=26, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=26, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=26, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=26, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=26, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=27, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=27, weights=uniform; total time=   1.6s
# [CV 3/5] END ................n_neighbors=27, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=27, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=27, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=27, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=27, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=27, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=27, weights=distance; total time=   1.7s
# [CV 5/5] END ...............n_neighbors=27, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=28, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=28, weights=uniform; total time=   1.7s
# [CV 3/5] END ................n_neighbors=28, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=28, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=28, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=28, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=28, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=28, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=28, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=28, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=29, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=29, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=29, weights=uniform; total time=   1.7s
# [CV 4/5] END ................n_neighbors=29, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=29, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=29, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=29, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=29, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=29, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=29, weights=distance; total time=   1.4s
# [CV 1/5] END ................n_neighbors=30, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=30, weights=uniform; total time=   1.7s
# [CV 3/5] END ................n_neighbors=30, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=30, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=30, weights=uniform; total time=   1.4s
# [CV 1/5] END ...............n_neighbors=30, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=30, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=30, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=30, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=30, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=31, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=31, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=31, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=31, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=31, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=31, weights=distance; total time=   1.8s
# [CV 2/5] END ...............n_neighbors=31, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=31, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=31, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=31, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=32, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=32, weights=uniform; total time=   1.7s
# [CV 3/5] END ................n_neighbors=32, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=32, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=32, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=32, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=32, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=32, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=32, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=32, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=33, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=33, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=33, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=33, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=33, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=33, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=33, weights=distance; total time=   1.7s
# [CV 3/5] END ...............n_neighbors=33, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=33, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=33, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=34, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=34, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=34, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=34, weights=uniform; total time=   1.4s
# [CV 5/5] END ................n_neighbors=34, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=34, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=34, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=34, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=34, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=34, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=35, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=35, weights=uniform; total time=   1.7s
# [CV 3/5] END ................n_neighbors=35, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=35, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=35, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=35, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=35, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=35, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=35, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=35, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=36, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=36, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=36, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=36, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=36, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=36, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=36, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=36, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=36, weights=distance; total time=   1.4s
# [CV 5/5] END ...............n_neighbors=36, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=37, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=37, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=37, weights=uniform; total time=   1.8s
# [CV 4/5] END ................n_neighbors=37, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=37, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=37, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=37, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=37, weights=distance; total time=   1.8s
# [CV 4/5] END ...............n_neighbors=37, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=37, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=38, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=38, weights=uniform; total time=   2.2s
# [CV 3/5] END ................n_neighbors=38, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=38, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=38, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=38, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=38, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=38, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=38, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=38, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=39, weights=uniform; total time=   1.5s
# [CV 2/5] END ................n_neighbors=39, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=39, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=39, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=39, weights=uniform; total time=   1.5s
# [CV 1/5] END ...............n_neighbors=39, weights=distance; total time=   1.5s
# [CV 2/5] END ...............n_neighbors=39, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=39, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=39, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=39, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=40, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=40, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=40, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=40, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=40, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=40, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=40, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=40, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=40, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=40, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=41, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=41, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=41, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=41, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=41, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=41, weights=distance; total time=   1.9s
# [CV 2/5] END ...............n_neighbors=41, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=41, weights=distance; total time=   1.9s
# [CV 4/5] END ...............n_neighbors=41, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=41, weights=distance; total time=   1.5s
# [CV 1/5] END ................n_neighbors=42, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=42, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=42, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=42, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=42, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=42, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=42, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=42, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=42, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=42, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=43, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=43, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=43, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=43, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=43, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=43, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=43, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=43, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=43, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=43, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=44, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=44, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=44, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=44, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=44, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=44, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=44, weights=distance; total time=   1.8s
# [CV 3/5] END ...............n_neighbors=44, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=44, weights=distance; total time=   1.8s
# [CV 5/5] END ...............n_neighbors=44, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=45, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=45, weights=uniform; total time=   1.8s
# [CV 3/5] END ................n_neighbors=45, weights=uniform; total time=   2.1s
# [CV 4/5] END ................n_neighbors=45, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=45, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=45, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=45, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=45, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=45, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=45, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=46, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=46, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=46, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=46, weights=uniform; total time=   1.5s
# [CV 5/5] END ................n_neighbors=46, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=46, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=46, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=46, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=46, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=46, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=47, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=47, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=47, weights=uniform; total time=   1.9s
# [CV 4/5] END ................n_neighbors=47, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=47, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=47, weights=distance; total time=   1.8s
# [CV 2/5] END ...............n_neighbors=47, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=47, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=47, weights=distance; total time=   1.5s
# [CV 5/5] END ...............n_neighbors=47, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=48, weights=uniform; total time=   1.9s
# [CV 2/5] END ................n_neighbors=48, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=48, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=48, weights=uniform; total time=   1.9s
# [CV 5/5] END ................n_neighbors=48, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=48, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=48, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=48, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=48, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=48, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=49, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=49, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=49, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=49, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=49, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=49, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=49, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=49, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=49, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=49, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=50, weights=uniform; total time=   1.6s
# [CV 2/5] END ................n_neighbors=50, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=50, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=50, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=50, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=50, weights=distance; total time=   1.6s
# [CV 2/5] END ...............n_neighbors=50, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=50, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=50, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=50, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=51, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=51, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=51, weights=uniform; total time=   2.3s
# [CV 4/5] END ................n_neighbors=51, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=51, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=51, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=51, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=51, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=51, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=51, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=52, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=52, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=52, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=52, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=52, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=52, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=52, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=52, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=52, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=52, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=53, weights=uniform; total time=   1.8s
# [CV 2/5] END ................n_neighbors=53, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=53, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=53, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=53, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=53, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=53, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=53, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=53, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=53, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=54, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=54, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=54, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=54, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=54, weights=uniform; total time=   2.1s
# [CV 1/5] END ...............n_neighbors=54, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=54, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=54, weights=distance; total time=   2.0s
# [CV 4/5] END ...............n_neighbors=54, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=54, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=55, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=55, weights=uniform; total time=   2.0s
# [CV 3/5] END ................n_neighbors=55, weights=uniform; total time=   2.0s
# [CV 4/5] END ................n_neighbors=55, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=55, weights=uniform; total time=   1.6s
# [CV 1/5] END ...............n_neighbors=55, weights=distance; total time=   1.8s
# [CV 2/5] END ...............n_neighbors=55, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=55, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=55, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=55, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=56, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=56, weights=uniform; total time=   1.9s
# [CV 3/5] END ................n_neighbors=56, weights=uniform; total time=   2.1s
# [CV 4/5] END ................n_neighbors=56, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=56, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=56, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=56, weights=distance; total time=   1.9s
# [CV 3/5] END ...............n_neighbors=56, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=56, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=56, weights=distance; total time=   1.6s
# [CV 1/5] END ................n_neighbors=57, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=57, weights=uniform; total time=   2.0s
# [CV 3/5] END ................n_neighbors=57, weights=uniform; total time=   2.1s
# [CV 4/5] END ................n_neighbors=57, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=57, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=57, weights=distance; total time=   1.8s
# [CV 2/5] END ...............n_neighbors=57, weights=distance; total time=   2.1s
# [CV 3/5] END ...............n_neighbors=57, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=57, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=57, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=58, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=58, weights=uniform; total time=   2.1s
# [CV 3/5] END ................n_neighbors=58, weights=uniform; total time=   2.1s
# [CV 4/5] END ................n_neighbors=58, weights=uniform; total time=   1.6s
# [CV 5/5] END ................n_neighbors=58, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=58, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=58, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=58, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=58, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=58, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=59, weights=uniform; total time=   1.7s
# [CV 2/5] END ................n_neighbors=59, weights=uniform; total time=   2.0s
# [CV 3/5] END ................n_neighbors=59, weights=uniform; total time=   2.3s
# [CV 4/5] END ................n_neighbors=59, weights=uniform; total time=   1.7s
# [CV 5/5] END ................n_neighbors=59, weights=uniform; total time=   1.7s
# [CV 1/5] END ...............n_neighbors=59, weights=distance; total time=   1.7s
# [CV 2/5] END ...............n_neighbors=59, weights=distance; total time=   2.0s
# [CV 3/5] END ...............n_neighbors=59, weights=distance; total time=   2.1s
# [CV 4/5] END ...............n_neighbors=59, weights=distance; total time=   1.6s
# [CV 5/5] END ...............n_neighbors=59, weights=distance; total time=   1.7s
# [CV 1/5] END ................n_neighbors=60, weights=uniform; total time=   1.7s
# ...
# [CV 5/5] END ...............n_neighbors=131, weights=uniform; total time=   2.2s
# [CV 1/5] END ..............n_neighbors=131, weights=distance; total time=   2.2s
# [CV 2/5] END ..............n_neighbors=131, weights=distance; total time=   2.5s
# [CV 3/5] END ..............n_neighbors=131, weights=distance; total time=   2.7s
# [CV 4/5] END ..............n_neighbors=131, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=131, weights=distance; total time=   2.2s
# [CV 1/5] END ...............n_neighbors=132, weights=uniform; total time=   2.2s
# [CV 2/5] END ...............n_neighbors=132, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=132, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=132, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=132, weights=uniform; total time=   2.2s
# [CV 1/5] END ..............n_neighbors=132, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=132, weights=distance; total time=   2.8s
# [CV 3/5] END ..............n_neighbors=132, weights=distance; total time=   2.7s
# [CV 4/5] END ..............n_neighbors=132, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=132, weights=distance; total time=   2.2s
# [CV 1/5] END ...............n_neighbors=133, weights=uniform; total time=   2.2s
# [CV 2/5] END ...............n_neighbors=133, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=133, weights=uniform; total time=   2.7s
# [CV 4/5] END ...............n_neighbors=133, weights=uniform; total time=   2.1s
# [CV 5/5] END ...............n_neighbors=133, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=133, weights=distance; total time=   2.2s
# [CV 2/5] END ..............n_neighbors=133, weights=distance; total time=   2.6s
# [CV 3/5] END ..............n_neighbors=133, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=133, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=133, weights=distance; total time=   2.4s
# [CV 1/5] END ...............n_neighbors=134, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=134, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=134, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=134, weights=uniform; total time=   2.1s
# [CV 5/5] END ...............n_neighbors=134, weights=uniform; total time=   2.2s
# [CV 1/5] END ..............n_neighbors=134, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=134, weights=distance; total time=   2.6s
# [CV 3/5] END ..............n_neighbors=134, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=134, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=134, weights=distance; total time=   2.4s
# [CV 1/5] END ...............n_neighbors=135, weights=uniform; total time=   2.5s
# [CV 2/5] END ...............n_neighbors=135, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=135, weights=uniform; total time=   2.7s
# [CV 4/5] END ...............n_neighbors=135, weights=uniform; total time=   2.1s
# [CV 5/5] END ...............n_neighbors=135, weights=uniform; total time=   2.5s
# [CV 1/5] END ..............n_neighbors=135, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=135, weights=distance; total time=   2.6s
# [CV 3/5] END ..............n_neighbors=135, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=135, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=135, weights=distance; total time=   2.2s
# [CV 1/5] END ...............n_neighbors=136, weights=uniform; total time=   2.4s
# [CV 2/5] END ...............n_neighbors=136, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=136, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=136, weights=uniform; total time=   2.1s
# [CV 5/5] END ...............n_neighbors=136, weights=uniform; total time=   2.2s
# [CV 1/5] END ..............n_neighbors=136, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=136, weights=distance; total time=   2.8s
# [CV 3/5] END ..............n_neighbors=136, weights=distance; total time=   3.0s
# [CV 4/5] END ..............n_neighbors=136, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=136, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=137, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=137, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=137, weights=uniform; total time=   2.9s
# [CV 4/5] END ...............n_neighbors=137, weights=uniform; total time=   2.6s
# [CV 5/5] END ...............n_neighbors=137, weights=uniform; total time=   2.5s
# [CV 1/5] END ..............n_neighbors=137, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=137, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=137, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=137, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=137, weights=distance; total time=   2.2s
# [CV 1/5] END ...............n_neighbors=138, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=138, weights=uniform; total time=   2.7s
# [CV 3/5] END ...............n_neighbors=138, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=138, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=138, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=138, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=138, weights=distance; total time=   2.9s
# [CV 3/5] END ..............n_neighbors=138, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=138, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=138, weights=distance; total time=   2.2s
# [CV 1/5] END ...............n_neighbors=139, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=139, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=139, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=139, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=139, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=139, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=139, weights=distance; total time=   2.8s
# [CV 3/5] END ..............n_neighbors=139, weights=distance; total time=   3.0s
# [CV 4/5] END ..............n_neighbors=139, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=139, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=140, weights=uniform; total time=   2.2s
# [CV 2/5] END ...............n_neighbors=140, weights=uniform; total time=   2.7s
# [CV 3/5] END ...............n_neighbors=140, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=140, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=140, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=140, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=140, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=140, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=140, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=140, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=141, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=141, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=141, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=141, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=141, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=141, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=141, weights=distance; total time=   2.6s
# [CV 3/5] END ..............n_neighbors=141, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=141, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=141, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=142, weights=uniform; total time=   2.6s
# [CV 2/5] END ...............n_neighbors=142, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=142, weights=uniform; total time=   3.9s
# [CV 4/5] END ...............n_neighbors=142, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=142, weights=uniform; total time=   2.7s
# [CV 1/5] END ..............n_neighbors=142, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=142, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=142, weights=distance; total time=   2.9s
# [CV 4/5] END ..............n_neighbors=142, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=142, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=143, weights=uniform; total time=   2.4s
# [CV 2/5] END ...............n_neighbors=143, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=143, weights=uniform; total time=   3.1s
# [CV 4/5] END ...............n_neighbors=143, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=143, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=143, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=143, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=143, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=143, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=143, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=144, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=144, weights=uniform; total time=   2.6s
# [CV 3/5] END ...............n_neighbors=144, weights=uniform; total time=   3.0s
# [CV 4/5] END ...............n_neighbors=144, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=144, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=144, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=144, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=144, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=144, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=144, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=145, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=145, weights=uniform; total time=   2.7s
# [CV 3/5] END ...............n_neighbors=145, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=145, weights=uniform; total time=   2.4s
# [CV 5/5] END ...............n_neighbors=145, weights=uniform; total time=   2.5s
# [CV 1/5] END ..............n_neighbors=145, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=145, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=145, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=145, weights=distance; total time=   2.1s
# [CV 5/5] END ..............n_neighbors=145, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=146, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=146, weights=uniform; total time=   3.1s
# [CV 3/5] END ...............n_neighbors=146, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=146, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=146, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=146, weights=distance; total time=   2.5s
# [CV 2/5] END ..............n_neighbors=146, weights=distance; total time=   2.9s
# [CV 3/5] END ..............n_neighbors=146, weights=distance; total time=   2.9s
# [CV 4/5] END ..............n_neighbors=146, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=146, weights=distance; total time=   3.9s
# [CV 1/5] END ...............n_neighbors=147, weights=uniform; total time=   2.6s
# [CV 2/5] END ...............n_neighbors=147, weights=uniform; total time=   2.8s
# [CV 3/5] END ...............n_neighbors=147, weights=uniform; total time=   2.9s
# [CV 4/5] END ...............n_neighbors=147, weights=uniform; total time=   2.3s
# [CV 5/5] END ...............n_neighbors=147, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=147, weights=distance; total time=   2.3s
# [CV 2/5] END ..............n_neighbors=147, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=147, weights=distance; total time=   3.1s
# [CV 4/5] END ..............n_neighbors=147, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=147, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=148, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=148, weights=uniform; total time=   2.7s
# [CV 3/5] END ...............n_neighbors=148, weights=uniform; total time=   2.9s
# [CV 4/5] END ...............n_neighbors=148, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=148, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=148, weights=distance; total time=   2.4s
# [CV 2/5] END ..............n_neighbors=148, weights=distance; total time=   2.6s
# [CV 3/5] END ..............n_neighbors=148, weights=distance; total time=   3.0s
# [CV 4/5] END ..............n_neighbors=148, weights=distance; total time=   2.3s
# [CV 5/5] END ..............n_neighbors=148, weights=distance; total time=   2.3s
# [CV 1/5] END ...............n_neighbors=149, weights=uniform; total time=   2.3s
# [CV 2/5] END ...............n_neighbors=149, weights=uniform; total time=   2.7s
# [CV 3/5] END ...............n_neighbors=149, weights=uniform; total time=   2.8s
# [CV 4/5] END ...............n_neighbors=149, weights=uniform; total time=   2.2s
# [CV 5/5] END ...............n_neighbors=149, weights=uniform; total time=   2.3s
# [CV 1/5] END ..............n_neighbors=149, weights=distance; total time=   2.4s
# [CV 2/5] END ..............n_neighbors=149, weights=distance; total time=   2.7s
# [CV 3/5] END ..............n_neighbors=149, weights=distance; total time=   2.8s
# [CV 4/5] END ..............n_neighbors=149, weights=distance; total time=   2.2s
# [CV 5/5] END ..............n_neighbors=149, weights=distance; total time=   2.3s
#     param_n_neighbors param_weights  mean_test_score  rank_test_score
# 211               106      distance         0.841115                1
# 219               110      distance         0.841112                2
# 215               108      distance         0.841111                3
# 207               104      distance         0.841110                4
# 217               109      distance         0.841108                5
# ..                ...           ...              ...              ...
# 5                   3      distance         0.774239              294
# 3                   2      distance         0.762011              295
# 2                   2       uniform         0.761906              296
# 1                   1      distance         0.736010              297
# 0                   1       uniform         0.736010              297
#
# [298 rows x 4 columns]

# %%
KNNuniform = KNN_results[(KNN_results['param_weights'] == 'uniform' )].sort_values(by = ['param_n_neighbors'])
KNNdistance = KNN_results[(KNN_results['param_weights'] == 'distance' )].sort_values(by = ['param_n_neighbors'])

plt.plot(KNNuniform['param_n_neighbors'], KNNuniform['mean_test_score'], label = 'uniform')
plt.plot(KNNdistance['param_n_neighbors'], KNNdistance['mean_test_score'], label = 'distance')

plt.xlabel('Param N Neighbors')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores for different parameter combinations of kNN')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
estimator = KNeighborsRegressor(n_neighbors = 104, weights = 'distance').fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

KNNMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions')
# Display a figure.
plt.show()
# Out:
# 10.957660120905222

# %%
plt.title('KNN predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()

# %% [markdown]
# # SVM Regression

# %%
SVM = GridSearchCV(svm.SVR(gamma='scale'), {
    'C': [0.01, 0.1, 1, 100], 
    'kernel': ['rbf','linear'],
    'epsilon': [0.01,0.1,1,10]
}, cv=5, return_train_score=False, verbose = 4)
SVM.fit(inputXscaled, inputy)

svm_results = pd.DataFrame(SVM.cv_results_)
svmresults = svm_results[['param_kernel','param_C','param_epsilon', 'mean_test_score', 'rank_test_score']].sort_values(by=['rank_test_score'])
svmresults
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  50.4s
# [CV 2/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  49.9s
# [CV 3/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  49.8s
# [CV 4/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  50.1s
# [CV 5/5] END ...............C=0.01, epsilon=0.01, kernel=rbf; total time=  51.3s
# [CV 1/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  27.9s
# [CV 2/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  28.0s
# [CV 3/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  27.5s
# [CV 4/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  27.6s
# [CV 5/5] END ............C=0.01, epsilon=0.01, kernel=linear; total time=  27.6s
# [CV 1/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  48.3s
# [CV 2/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  49.0s
# [CV 3/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  50.3s
# [CV 4/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  48.7s
# [CV 5/5] END ................C=0.01, epsilon=0.1, kernel=rbf; total time=  48.3s
# [CV 1/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  27.1s
# [CV 2/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  26.9s
# [CV 3/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  26.6s
# [CV 4/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  26.9s
# [CV 5/5] END .............C=0.01, epsilon=0.1, kernel=linear; total time=  26.8s
# [CV 1/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.2s
# [CV 2/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  32.0s
# [CV 3/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.2s
# [CV 4/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.1s
# [CV 5/5] END ..................C=0.01, epsilon=1, kernel=rbf; total time=  31.7s
# [CV 1/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  15.9s
# [CV 2/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.4s
# [CV 3/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.4s
# [CV 4/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.1s
# [CV 5/5] END ...............C=0.01, epsilon=1, kernel=linear; total time=  16.2s
# [CV 1/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=   1.3s
# [CV 2/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=   1.4s
# [CV 3/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=   1.1s
# [CV 4/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=   1.0s
# [CV 5/5] END .................C=0.01, epsilon=10, kernel=rbf; total time=   1.4s
# [CV 1/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   0.1s
# [CV 2/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   0.1s
# [CV 3/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   0.0s
# [CV 4/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   0.1s
# [CV 5/5] END ..............C=0.01, epsilon=10, kernel=linear; total time=   0.1s
# [CV 1/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  52.8s
# [CV 2/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  50.7s
# [CV 3/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  50.1s
# [CV 4/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  50.3s
# [CV 5/5] END ................C=0.1, epsilon=0.01, kernel=rbf; total time=  50.3s
# [CV 1/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  28.7s
# [CV 2/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  29.1s
# [CV 3/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  28.9s
# [CV 4/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  29.1s
# [CV 5/5] END .............C=0.1, epsilon=0.01, kernel=linear; total time=  29.0s
# [CV 1/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  48.0s
# [CV 2/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  48.1s
# [CV 3/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  48.0s
# [CV 4/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  48.4s
# [CV 5/5] END .................C=0.1, epsilon=0.1, kernel=rbf; total time=  49.2s
# [CV 1/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  27.6s
# [CV 2/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  27.9s
# [CV 3/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  27.4s
# [CV 4/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  27.1s
# [CV 5/5] END ..............C=0.1, epsilon=0.1, kernel=linear; total time=  26.9s
# [CV 1/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  25.5s
# [CV 2/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  26.5s
# [CV 3/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  25.3s
# [CV 4/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  25.5s
# [CV 5/5] END ...................C=0.1, epsilon=1, kernel=rbf; total time=  26.1s
# [CV 1/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.7s
# [CV 2/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  18.0s
# [CV 3/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.7s
# [CV 4/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  17.0s
# [CV 5/5] END ................C=0.1, epsilon=1, kernel=linear; total time=  16.2s
# [CV 1/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=   0.5s
# [CV 2/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=   0.5s
# [CV 3/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=   0.3s
# [CV 4/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=   0.3s
# [CV 5/5] END ..................C=0.1, epsilon=10, kernel=rbf; total time=   0.5s
# [CV 1/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   0.0s
# [CV 2/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   0.0s
# [CV 3/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   0.0s
# [CV 4/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   0.2s
# [CV 5/5] END ...............C=0.1, epsilon=10, kernel=linear; total time=   0.1s
# [CV 1/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  50.4s
# [CV 2/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  50.4s
# [CV 3/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  49.7s
# [CV 4/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  50.5s
# [CV 5/5] END ..................C=1, epsilon=0.01, kernel=rbf; total time=  49.9s
# [CV 1/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  38.4s
# [CV 2/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  38.3s
# [CV 3/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  38.1s
# [CV 4/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  37.5s
# [CV 5/5] END ...............C=1, epsilon=0.01, kernel=linear; total time=  38.0s
# [CV 1/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  47.1s
# [CV 2/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  47.6s
# [CV 3/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  47.8s
# [CV 4/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  50.9s
# [CV 5/5] END ...................C=1, epsilon=0.1, kernel=rbf; total time=  47.9s
# [CV 1/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  38.3s
# [CV 2/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  38.3s
# [CV 3/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  38.0s
# [CV 4/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  38.3s
# [CV 5/5] END ................C=1, epsilon=0.1, kernel=linear; total time=  39.5s
# [CV 1/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  22.8s
# [CV 2/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  24.3s
# [CV 3/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  23.4s
# [CV 4/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  23.1s
# [CV 5/5] END .....................C=1, epsilon=1, kernel=rbf; total time=  24.0s
# [CV 1/5] END ..................C=1, epsilon=1, kernel=linear; total time=  24.0s
# [CV 2/5] END ..................C=1, epsilon=1, kernel=linear; total time=  24.6s
# [CV 3/5] END ..................C=1, epsilon=1, kernel=linear; total time=  24.3s
# [CV 4/5] END ..................C=1, epsilon=1, kernel=linear; total time=  23.8s
# [CV 5/5] END ..................C=1, epsilon=1, kernel=linear; total time=  24.2s
# [CV 1/5] END ....................C=1, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 2/5] END ....................C=1, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 3/5] END ....................C=1, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 4/5] END ....................C=1, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 5/5] END ....................C=1, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 1/5] END .................C=1, epsilon=10, kernel=linear; total time=   0.2s
# [CV 2/5] END .................C=1, epsilon=10, kernel=linear; total time=   0.3s
# [CV 3/5] END .................C=1, epsilon=10, kernel=linear; total time=   0.2s
# [CV 4/5] END .................C=1, epsilon=10, kernel=linear; total time=   0.2s
# [CV 5/5] END .................C=1, epsilon=10, kernel=linear; total time=   0.2s
# [CV 1/5] END ................C=100, epsilon=0.01, kernel=rbf; total time= 5.1min
# [CV 2/5] END ................C=100, epsilon=0.01, kernel=rbf; total time= 4.7min
# [CV 3/5] END ................C=100, epsilon=0.01, kernel=rbf; total time= 4.1min
# [CV 4/5] END ................C=100, epsilon=0.01, kernel=rbf; total time= 4.9min
# [CV 5/5] END ................C=100, epsilon=0.01, kernel=rbf; total time= 4.4min
# [CV 1/5] END .............C=100, epsilon=0.01, kernel=linear; total time=13.9min
# [CV 2/5] END .............C=100, epsilon=0.01, kernel=linear; total time=13.7min
# [CV 3/5] END .............C=100, epsilon=0.01, kernel=linear; total time=13.2min
# [CV 4/5] END .............C=100, epsilon=0.01, kernel=linear; total time=13.3min
# [CV 5/5] END .............C=100, epsilon=0.01, kernel=linear; total time=14.2min
# [CV 1/5] END .................C=100, epsilon=0.1, kernel=rbf; total time= 4.6min
# [CV 2/5] END .................C=100, epsilon=0.1, kernel=rbf; total time= 4.4min
# [CV 3/5] END .................C=100, epsilon=0.1, kernel=rbf; total time= 3.7min
# [CV 4/5] END .................C=100, epsilon=0.1, kernel=rbf; total time= 4.4min
# [CV 5/5] END .................C=100, epsilon=0.1, kernel=rbf; total time= 4.2min
# [CV 1/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=13.7min
# [CV 2/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=13.7min
# [CV 3/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=13.0min
# [CV 4/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=13.0min
# [CV 5/5] END ..............C=100, epsilon=0.1, kernel=linear; total time=14.1min
# [CV 1/5] END ...................C=100, epsilon=1, kernel=rbf; total time= 1.2min
# [CV 2/5] END ...................C=100, epsilon=1, kernel=rbf; total time= 1.3min
# [CV 3/5] END ...................C=100, epsilon=1, kernel=rbf; total time= 1.1min
# [CV 4/5] END ...................C=100, epsilon=1, kernel=rbf; total time= 1.2min
# [CV 5/5] END ...................C=100, epsilon=1, kernel=rbf; total time= 1.2min
# [CV 1/5] END ................C=100, epsilon=1, kernel=linear; total time= 9.4min
# [CV 2/5] END ................C=100, epsilon=1, kernel=linear; total time= 9.5min
# [CV 3/5] END ................C=100, epsilon=1, kernel=linear; total time= 9.4min
# [CV 4/5] END ................C=100, epsilon=1, kernel=linear; total time= 8.9min
# [CV 5/5] END ................C=100, epsilon=1, kernel=linear; total time= 9.2min
# [CV 1/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 2/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 3/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 4/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 5/5] END ..................C=100, epsilon=10, kernel=rbf; total time=   0.1s
# [CV 1/5] END ...............C=100, epsilon=10, kernel=linear; total time=   0.4s
# [CV 2/5] END ...............C=100, epsilon=10, kernel=linear; total time=   0.4s
# [CV 3/5] END ...............C=100, epsilon=10, kernel=linear; total time=   0.2s
# [CV 4/5] END ...............C=100, epsilon=10, kernel=linear; total time=   0.3s
# [CV 5/5] END ...............C=100, epsilon=10, kernel=linear; total time=   0.3s
#    param_kernel param_C param_epsilon  mean_test_score  rank_test_score
# 18          rbf       1           0.1         0.828788                1
# 20          rbf       1             1         0.828589                2
# 16          rbf       1          0.01         0.828549                3
# 10          rbf     0.1           0.1         0.818895                4
# 8           rbf     0.1          0.01         0.818780                5
# 12          rbf     0.1             1         0.818037                6
# 5        linear    0.01             1         0.781346                7
# 13       linear     0.1             1         0.781116                8
# 29       linear     100             1         0.781014                9
# 21       linear       1             1         0.780989               10
# 3        linear    0.01           0.1         0.779795               11
# 1        linear    0.01          0.01         0.779688               12
# 11       linear     0.1           0.1         0.779645               13
# 19       linear       1           0.1         0.779532               14
# 27       linear     100           0.1         0.779523               15
# 9        linear     0.1          0.01         0.779320               16
# 25       linear     100          0.01         0.779281               17
# 17       linear       1          0.01         0.779273               18
# 28          rbf     100             1         0.768750               19
# 26          rbf     100           0.1         0.756204               20
# 24          rbf     100          0.01         0.753451               21
# 0           rbf    0.01          0.01         0.677786               22
# 2           rbf    0.01           0.1         0.677755               23
# 4           rbf    0.01             1         0.671673               24
# 23       linear       1            10         0.516305               25
# 31       linear     100            10         0.511233               26
# 15       linear     0.1            10         0.220375               27
# 7        linear    0.01            10        -0.197978               28
# 30          rbf     100            10        -0.314729               29
# 22          rbf       1            10        -0.329963               30
# 14          rbf     0.1            10        -0.403084               31
# 6           rbf    0.01            10        -0.496856               32

# %%
#from sklearn.model_selection import train_test_split

#X_train,X_test,y_train,y_test = train_test_split(X1scaled,y1,test_size=0.25,random_state=42) #split training:testing 75:25


estimator = svm.SVR(C = 1,  kernel = 'rbf', epsilon = 0.1).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions')
# Display a figure.
plt.show()
# Out:
# 9.97874576043716

# %%
pred = estimator.predict(testXscaled)

SVMMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(SVMMAPE)

plt.title('SVM predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 9.97874576043716

# %% [markdown]
# # Multilayer perceptron

# %%
from sklearn.neural_network import MLPRegressor

layers = range(1,35)

parameters = {'hidden_layer_sizes': layers, 'solver': ['lbfgs', 'adam'], 'max_iter': [3000], 'learning_rate_init': 10.0 ** -np.arange(1, 6, 2), 'random_state':[42]}
MLPReg = GridSearchCV(MLPRegressor(), parameters, cv=5,  verbose=2, return_train_score=False)
MLPReg.fit(inputXscaled, inputy)

MLPRegRes = pd.DataFrame(MLPReg.cv_results_)
MLP_results = MLPRegRes[['rank_test_score', 'mean_test_score', 'param_hidden_layer_sizes', 'param_solver', 'param_max_iter', 'param_learning_rate_init']].sort_values(by=['rank_test_score'])
MLP_results
# Out:
# Fitting 5 folds for each of 204 candidates, totalling 1020 fits
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.6s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.6s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   6.9s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.7s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   7.6s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   7.0s
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   6.4s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.5min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.3s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.8s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.6s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   9.6s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.9s
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.5s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.2s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.0s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.7s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.9s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.5s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  19.6s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  16.2s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  12.9s
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  16.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.3s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.4s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.2s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  22.6s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   8.8s
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   7.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   1.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.5s
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.6min
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.3s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.3s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  14.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   9.4s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  25.2s
# [CV] END hidden_layer_sizes=5, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.7s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.9s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.8s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.1s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.5s
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=5, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   5.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  14.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.5s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   5.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  14.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.6s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.2s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  13.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.0s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.9s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.4s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  15.8s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   2.7s
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=6, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.5s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.0s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.5s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.0s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.0s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.2s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   9.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   8.9s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   9.4s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=   8.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.7s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.3s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.1s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   3.6s
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=7, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.5s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  11.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.4s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.6s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.8s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.9s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  15.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  18.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  16.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  14.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  20.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  14.0s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   9.3s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  10.1s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  11.2s
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=8, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.1s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   5.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   0.8s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.8s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.5s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   5.2s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   7.5s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  12.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  13.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  21.0s
# [CV] END hidden_layer_sizes=9, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  11.3s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   5.7s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   4.9s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  12.5s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   6.6s
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=9, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  21.3s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  16.8s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  12.2s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.4s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  11.9s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.0s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.4s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.6s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   1.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  22.0s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  17.9s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  13.3s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=   8.9s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  12.3s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  15.4s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.3s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  21.2s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  14.1s
# [CV] END hidden_layer_sizes=10, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  10.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  57.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  57.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  57.3s
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.7min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.8min
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.3min
# [CV] END hidden_layer_sizes=33, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.4min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time= 1.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time= 1.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.0s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   3.8s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   3.0s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   2.6s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   3.7s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.1, max_iter=3000, random_state=42, solver=adam; total time=   4.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time= 1.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.2s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  22.2s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  25.6s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  20.3s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  17.9s
# [CV] END hidden_layer_sizes=34, learning_rate_init=0.001, max_iter=3000, random_state=42, solver=adam; total time=  20.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time= 1.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  59.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=lbfgs; total time=  58.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END hidden_layer_sizes=34, learning_rate_init=1e-05, max_iter=3000, random_state=42, solver=adam; total time= 2.7min
#      rank_test_score  mean_test_score param_hidden_layer_sizes param_solver  \
# 24                 1         0.853506                        5        lbfgs
# 26                 1         0.853506                        5        lbfgs
# 28                 1         0.853506                        5        lbfgs
# 21                 4         0.851356                        4         adam
# 191                5         0.848317                       32         adam
# ..               ...              ...                      ...          ...
# 4                199         0.495541                        1        lbfgs
# 0                199         0.495541                        1        lbfgs
# 3                202        -0.097901                        1         adam
# 11               203        -1.258332                        2         adam
# 5                204        -6.852147                        1         adam
#
#     param_max_iter param_learning_rate_init
# 24            3000                      0.1
# 26            3000                    0.001
# 28            3000                  0.00001
# 21            3000                    0.001
# 191           3000                  0.00001
# ..             ...                      ...
# 4             3000                  0.00001
# 0             3000                      0.1
# 3             3000                    0.001
# 11            3000                  0.00001
# 5             3000                  0.00001
#
# [204 rows x 6 columns]

# %%
MLP_results1 = MLP_results[MLP_results['mean_test_score']>0.5]


MLP_adam = MLP_results1[(MLP_results1['param_solver'] == 'adam' )].sort_values(by = ['param_hidden_layer_sizes'])
MLP_lbfgs = MLP_results1[(MLP_results1['param_solver'] == 'lbfgs' )].sort_values(by = ['param_hidden_layer_sizes'])

plt.plot(MLP_adam['param_hidden_layer_sizes'], MLP_adam['mean_test_score'], label = 'adam')
plt.plot(MLP_lbfgs['param_hidden_layer_sizes'], MLP_lbfgs['mean_test_score'], label = 'lbfgs')

plt.xlabel('Number of hidden layers')
# Set the y axis label of the current axis.
plt.ylabel('Mean test Score')
# Set a title of the current axes.
plt.title('Test scores of different number of hidden layers for Multi Layer Perceptron')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
estimator = MLPRegressor(hidden_layer_sizes=5, solver = 'lbfgs', max_iter=3000, learning_rate_init=0.1, random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions')
# Display a figure.
plt.show()
# Out:
# 9.876182942578653

# %%
pred = estimator.predict(testXscaled)

MLPMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(MLPMAPE)

plt.title('Multi Layer Perceptron predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()
# Out:
# 9.876182942578653

# %% [markdown]
# # Adding more features

# %%
df = pd.read_excel("BaseFeaturesHH.xlsx")
df = df.drop('Unnamed: 0', axis = 1)
df
# Out:
#            From Timestamp  HH Electricity (kWh)  dayofweek  hour  holiday  \
# 0     2018-01-01 00:00:00                 12.80          0   0.0        1
# 1     2018-01-01 00:30:00                 12.30          0   0.5        1
# 2     2018-01-01 01:00:00                 13.50          0   1.0        1
# 3     2018-01-01 01:30:00                 11.90          0   1.5        1
# 4     2018-01-01 02:00:00                 12.80          0   2.0        1
# ...                   ...                   ...        ...   ...      ...
# 35035 2019-12-31 21:30:00                 13.56          1  21.5        0
# 35036 2019-12-31 22:00:00                 13.81          1  22.0        0
# 35037 2019-12-31 22:30:00                 14.12          1  22.5        0
# 35038 2019-12-31 23:00:00                 14.50          1  23.0        0
# 35039 2019-12-31 23:30:00                 13.88          1  23.5        0
#
#        month  Temperature (C)  Feels like (C)  Humidity (%)
# 0          1              6.4             1.9         82.76
# 1          1              6.4             1.9         82.76
# 2          1              6.6             2.4         80.14
# 3          1              6.6             2.4         80.14
# 4          1              6.1             2.0         84.33
# ...      ...              ...             ...           ...
# 35035     12              6.5             3.3         88.23
# 35036     12              6.6             4.4         87.69
# 35037     12              6.6             4.4         87.69
# 35038     12              6.7             4.1         88.13
# 35039     12              6.7             4.1         88.13
#
# [35040 rows x 9 columns]

# %%
lagNumberStart = 48
lagNumberEnd = 8*48

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(i)
    df[name] = df['HH Electricity (kWh)'].shift(i)

i = list(range(lagNumberEnd))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting

size = -int(len(df)*0.2)

Xinput = df.iloc[:size]
Xtest = df.iloc[size:] # 20%

size2 = -int(len(Xused)*0.25)

Xtrain = Xinput.iloc[:size2].copy() #60%
Xvalidate = Xinput.iloc[size2:].copy() #20%

trainX = Xtrain[feature_cols] # Features
trainy = Xtrain['HH Electricity (kWh)'] # Target variable

validateX = Xvalidate[feature_cols] # Features
validatey = Xvalidate['HH Electricity (kWh)'] # Target variable

testX = Xtest[feature_cols] # Features
testy = Xtest['HH Electricity (kWh)'] # Target variable

inputX = Xinput[feature_cols] # Features
inputy = Xinput['HH Electricity (kWh)'] # Target variable

scaler = StandardScaler() #scaling
scaler.fit(X)
trainXscaled = scaler.transform(trainX)
validateXscaled = scaler.transform(validateX)
testXscaled = scaler.transform(testX)
inputXscaled = scaler.transform(inputX)

# %%
estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(inputXscaled, inputy)
y_pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(testy,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()

# %%
pred = estimator.predict(testXscaled)

RandomForestMAPE = mean_absolute_percentage_error(testy, pred) * 100
print(RandomForestMAPE)

plt.title('Random Forest Regressor predictions')
plt.plot(df['From Timestamp'].iloc[size:],testy, label = "True value")
plt.plot(df['From Timestamp'].iloc[size:],pred, label = "Predicted value")
# show a legend on the plot
plt.xlabel('Timestamp')
plt.ylabel('Electricity (kWh)')
plt.legend()

# %% [markdown]
# # Random Split

# %%
df = pd.read_excel("BaseFeaturesHH.xlsx")
df = df.drop('Unnamed: 0', axis = 1)

lagNumberStart = 1
lagNumberEnd = 8

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    df[name] = df['HH Electricity (kWh)'].shift(48*i)

i = list(range(lagNumberEnd*48))
df = df.drop(i)


feature_cols = ['dayofweek', 'hour', 'month', 'holiday', 'Temperature (C)', 'Feels like (C)', 'Humidity (%)']   

for i in range(lagNumberStart, lagNumberEnd):
    name = "n-{}.".format(48*i)
    feature_cols.append(name)
    
X = df[feature_cols].copy() #input features for fitting
Y = df[['HH Electricity (kWh)']]


scaler = StandardScaler() #scaling
scaler.fit(X)
Xscaled = scaler.transform(X)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Xscaled,Y,test_size=0.20,random_state=42) #split training:testing 80:20

# %%
estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(X_train, ravel(y_train))
y_pred = estimator.predict(X_test)

RandomForestMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(RandomForestMAPE)

from matplotlib.figure import Figure as figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Random Forest Regressor predictions')
# Display a figure.
plt.show()
# Out:
# <ipython-input-180-ed12b10fd0af>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator = RandomForestRegressor(n_estimators = 1000,  random_state=42).fit(X_train, y_train)
# 5.301960797789791

# %%
estimator = KNeighborsRegressor(n_neighbors = 104, weights = 'distance').fit(X_train, y_train)
y_pred = estimator.predict(X_test)

KNNMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(KNNMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('KNN predictions')
# Display a figure.
plt.show()
# Out:
# 7.654330433078378

# %%
estimator = svm.SVR(C = 1,  kernel = 'rbf', epsilon = 0.1).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

SVMMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(SVMMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('SVM predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 7.325068194913794

# %%
from sklearn.neural_network import MLPRegressor

layers = range(1,30)

parameters = {'hidden_layer_sizes': layers, 'solver': ['lbfgs', 'adam'], 'max_iter': [2500], 'learning_rate_init': 10.0 ** -np.arange(1, 6, 2), 'random_state':[42]}
MLPReg = GridSearchCV(MLPRegressor(), parameters, cv=5,  verbose=2, return_train_score=False)
MLPReg.fit(X_train, y_train)

MLPRegRes = pd.DataFrame(MLPReg.cv_results_)
MLP_results = MLPRegRes[['rank_test_score', 'mean_test_score', 'param_hidden_layer_sizes', 'param_solver', 'param_max_iter', 'param_learning_rate_init']].sort_values(by=['rank_test_score'])
MLP_results
# Out:
# Fitting 5 folds for each of 174 candidates, totalling 870 fits
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   9.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=   8.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   0.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.6min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=1, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.7min
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.0min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=2, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.2min
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  16.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  15.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  26.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  14.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   5.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   1.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   2.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.1min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.8min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=3, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 1.9min
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   7.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   0.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   1.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   6.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  13.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  17.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  27.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   7.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   4.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=4, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=   3.8s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   3.2s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.1, max_iter=2500, random_state=42, solver=adam; total time=   2.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  49.0s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.3s
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  23.7s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  28.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  21.3s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=0.001, max_iter=2500, random_state=42, solver=adam; total time=  22.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.1s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.5s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.9s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  48.6s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=lbfgs; total time=  47.4s
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [CV] END hidden_layer_sizes=29, learning_rate_init=1e-05, max_iter=2500, random_state=42, solver=adam; total time= 2.3min
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#      rank_test_score  mean_test_score param_hidden_layer_sizes param_solver  \
# 172                1         0.901754                       29        lbfgs
# 170                1         0.901754                       29        lbfgs
# 168                1         0.901754                       29        lbfgs
# 124                4         0.899988                       21        lbfgs
# 122                4         0.899988                       21        lbfgs
# ..               ...              ...                      ...          ...
# 23               170         0.653448                        4         adam
# 41               171         0.618623                        7         adam
# 3                172        -0.000212                        1         adam
# 11               173        -2.319447                        2         adam
# 5                174        -7.063683                        1         adam
#
#     param_max_iter param_learning_rate_init
# 172           2500                  0.00001
# 170           2500                    0.001
# 168           2500                      0.1
# 124           2500                  0.00001
# 122           2500                    0.001
# ..             ...                      ...
# 23            2500                  0.00001
# 41            2500                  0.00001
# 3             2500                    0.001
# 11            2500                  0.00001
# 5             2500                  0.00001
#
# [174 rows x 6 columns]

# %%
estimator = MLPRegressor(hidden_layer_sizes=5, solver = 'lbfgs', max_iter=3000, learning_rate_init=0.1, random_state=42).fit(X_train, y_train)
y_pred = estimator.predict(X_test)

MLPMAPE = mean_absolute_percentage_error(y_test, y_pred) * 100
print(MLPMAPE)

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)
plt.scatter(y_test,y_pred, s = 2.5)
plt.xlabel('Real Value')
# Set the y axis label of the current axis.
plt.ylabel('Predicted value')
# Set a title of the current axes.
plt.title('Multi Layer Perceptron predictions')
# Display a figure.
plt.show()
# Out:
# C:\Users\salda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 8.597355117603344
