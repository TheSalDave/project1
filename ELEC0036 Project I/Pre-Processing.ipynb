# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('ProjectDataOriginal.xlsx')

# %%
df
# Out:
#            From Timestamp  HH Electrical (kWh)  HH Chilled Water (kWh)  \
# 0     2018-01-01 00:00:00                12.80                  0.5498
# 1     2018-01-01 00:30:00                12.30                  0.5195
# 2     2018-01-01 01:00:00                13.50                  0.5742
# 3     2018-01-01 01:30:00                11.90                  0.5928
# 4     2018-01-01 02:00:00                12.80                  0.6143
# ...                   ...                  ...                     ...
# 35035 2019-12-31 21:30:00                13.56                  0.7700
# 35036 2019-12-31 22:00:00                13.81                  0.7200
# 35037 2019-12-31 22:30:00                14.12                  0.6500
# 35038 2019-12-31 23:00:00                14.50                  0.6600
# 35039 2019-12-31 23:30:00                13.88                  0.0400
#
#        HH LTHW (Heating) (kWh)  HH CHW Capacity (m3)  DE Electricity (kWh)  \
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('HH Electric', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['HH Electrical (kWh)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Electrical in kWh', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['HH Electrical (kWh)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('HH Chilled Water', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['HH Chilled Water (kWh)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which='major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Electrical in kWh', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['HH Chilled Water (kWh)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('HH LTHW (Heating)', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['HH LTHW (Heating) (kWh)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Energy in kWh', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['HH LTHW (Heating) (kWh)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('HH CHW Capacity (m3)', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['HH CHW Capacity (m3)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Capacity in m3', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['HH CHW Capacity (m3)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('DE Electricity (kWh)', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['DE Electricity (kWh)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Energy in kWh', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['DE Electricity (kWh)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('DE LTHW (Heating) (kWh)', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['DE LTHW (Heating) (kWh)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Energy in kWh', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['DE LTHW (Heating) (kWh)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('DE CHW Capacity (m3)', fontsize = 40)
red_square = dict(markerfacecolor='r', marker='s')
data = df['DE CHW Capacity (m3)']
filtered_data = data[~np.isnan(data)]
ax1.boxplot(filtered_data, flierprops=red_square)
ax1.tick_params(axis='both', which='major', labelsize=20)

plt.grid(which = 'major')
plt.xlabel('Timestamp', fontsize = 30)
plt.ylabel('Capacity in m3', fontsize = 30)
ax2.scatter(x = df['From Timestamp'], y = df['DE CHW Capacity (m3)'], s = 30)
ax2.tick_params(axis='both', which='major', labelsize=20)

plt.rcParams['figure.figsize'] = [40, 10]

plt.show()
