# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('ProjectData.xlsx', sheet_name='HH_Electrical_2018')
df1 = df[['From Timestamp','Hursley House EHH3 (kWh)']] #to get rid of the random columns
Data1 = df[['Hursley House EHH3 (kWh)']] #extracting the data
time1 = df[['From Timestamp']]
df = pd.read_excel('ProjectData.xlsx', sheet_name='HH Electrical 2019')
df2 = df[['From Timestamp','Hursley House.Electric Meter - Hursley House EHH3 (kWh)']] #to get rid of the random columns
Data2 = df[['Hursley House.Electric Meter - Hursley House EHH3 (kWh)']] #extracting the data
time2 = df[['From Timestamp']]
Data = pd.concat([Data1,Data2])
time = pd.concat([time1,time2])

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time, Data, 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (YYYY-MM)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Original electric load HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Original electric load HH Electrical (kWh)')

# %%
print(len(time))
print(len(Data))
# Out:
# 17520
# 17520

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time, HHcorrect, 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (YYYY-MM)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Electric load after cleaning algorithm for HH', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Electric load after cleaning algorithm for HH')

# %%
n=1

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[(n-1)*48:n*48], Data[(n-1)*48:n*48], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 1 HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Day 1 HH Electrical (kWh)')

# %%
n=2

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[(n-1)*48:n*48], Data[(n-1)*48:n*48], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 2 HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Day 2 HH Electrical (kWh)')

# %%
n=3

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[(n-1)*48:n*48], Data[(n-1)*48:n*48], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 3 HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Day 3 HH Electrical (kWh)')

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[36*48:37*48], Data[36*48:37*48], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 1 HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Anomaly 1 HH Electrical (kWh)')

# %%
correct1 = pd.read_excel('BaseFeaturesHH.xlsx')
HHcorrect = correct1['HH Electricity (kWh)']
correct2 = pd.read_excel('BaseFeaturesDE.xlsx')
DEcorrect = correct2['DE Electricity (kWh)']

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[36*48:37*48],HHcorrect[36*48:37*48], 'b')
plt.plot(time[36*48:37*48], Data[36*48:37*48], 'r--')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 1 HH Electrical (kWh)', fontsize = 32)
plt.legend(['After','Before'], fontsize=25)

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[12240:12288], Data[12240:12288], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 2 HH Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Anomaly 2 HH Electrical (kWh)')

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[12240:12288],HHcorrect[12240:12288], 'b')
plt.plot(time[12240:12288], Data[12240:12288], 'r--')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 2 HH Electrical (kWh)', fontsize = 32)
plt.legend(['After','Before'], fontsize=25)

# %% [markdown]
# # Moving on to DE

# %%
df = pd.read_excel('ProjectData.xlsx', sheet_name='DE Elec 2019')

df = pd.read_excel('ProjectData.xlsx', sheet_name='DE Elec 2018')
df1 = df[['From Timestamp','Block D East.Electric Meter - D East Total EDE3 (kWh)']] #to get rid of the random columns
Data1 = df[['Block D East.Electric Meter - D East Total EDE3 (kWh)']] #extracting the data
time1 = df[['From Timestamp']]
df = pd.read_excel('ProjectData.xlsx', sheet_name='DE Elec 2019')
df2 = df[['From Timestamp','Block D East.Electric Meter - D East Total EDE3 (kWh)']] #to get rid of the random columns
Data2 = df[['Block D East.Electric Meter - D East Total EDE3 (kWh)']] #extracting the data
time2 = df[['From Timestamp']]
DataDE = pd.concat([Data1,Data2])
timeDE = pd.concat([time1,time2])

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(timeDE, DataDE, 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (YYYY-MM)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Electric load DE Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Electric load DE Electrical (kWh)')

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(timeDE[-len(DEcorrect):], DEcorrect, 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (YYYY-MM)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Electric load after cleaning algorithm for DE', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Electric load after cleaning algorithm for DE')

# %%
len(DEcorrect)
# Out:
# 28829

# %%
n=1

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(timeDE[(n-1)*48+len(timeDE)-len(DEcorrect)+29:n*48+len(timeDE)-len(DEcorrect)+29], DataDE[(n-1)*48+len(DataDE)-len(DEcorrect)+29:29+n*48+len(DataDE)-len(DEcorrect)], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 1 DE Electrical (kWh)', fontsize = 32)
plt.ylim([210,350])
# Out:
# (210.0, 350.0)

# %%
n=2

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(timeDE[(n-1)*48+len(timeDE)-len(DEcorrect)+29:n*48+len(timeDE)-len(DEcorrect)+29], DataDE[(n-1)*48+len(DataDE)-len(DEcorrect)+29:29+n*48+len(DataDE)-len(DEcorrect)], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 2 DE Electrical (kWh)', fontsize = 32)
plt.ylim([210,350])
# Out:
# (210.0, 350.0)

# %%
n=4

plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(timeDE[(n-1)*48+len(timeDE)-len(DEcorrect)+29:n*48+len(timeDE)-len(DEcorrect)+29], DataDE[(n-1)*48+len(DataDE)-len(DEcorrect)+29:29+n*48+len(DataDE)-len(DEcorrect)], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Day 4 DE Electrical (kWh)', fontsize = 32)
plt.ylim([210,350])
# Out:
# (210.0, 350.0)

# %%
len(df1)
# Out:
# 17520

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[6817-17520:6865+17520], DataDE[6817+17520:6865+17520], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 4 DE Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Anomaly 4 DE Electrical (kWh)')

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[6817-17520:6865+17520],DEcorrect[18126:18126+48], 'b')
plt.plot(time[6817-17520:6865+17520], DataDE[6817+17520:6865+17520], 'r--')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 4 DE Electrical (kWh)', fontsize = 32)
plt.legend(['After','Before'], fontsize=25)

# %%
df = pd.read_excel('ProjectData.xlsx', sheet_name='DE Elec 2018')

Data = df[['Block D East.Electric Meter - D East Total EDE3 (kWh)']] #extracting the data
time = df[['From Timestamp']]

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[14353:14449], Data[14353:14449], 'r')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 3 DE Electrical (kWh)', fontsize = 32)
# Out:
# Text(0.5, 1.0, 'Anomaly 3 DE Electrical (kWh)')

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[14352:14448],DEcorrect[8141:8237], 'b')
plt.plot(time[14352:14448], DataDE[14352:14448], 'r--')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (MM-DD HH)', fontsize = 27)
plt.ylabel('Electrical in kWh', fontsize = 27)
plt.tick_params(axis='both', which='major', labelsize=16.5)
plt.title('Anomaly 3 DE Electrical (kWh)', fontsize = 32)
plt.legend(['After','Before'], fontsize=25)

# %% [markdown]
# ### Searching for inconsistent points even after the cleaning

# %%
a=25000

plt.plot(correct2['From Timestamp'][a:a+1000],correct2['DE Electricity (kWh)'][a:a+1000])

# %%
a=25620

plt.plot(correct2['From Timestamp'][a:a+100],correct2['DE Electricity (kWh)'][a:a+100])

# %%
correct1 = pd.read_excel('BaseFeaturesHH.xlsx')
HHcorrect = correct1['HH Electricity (kWh)']
correct2 = pd.read_excel('BaseFeaturesDE.xlsx')
DEcorrect = correct2['DE Electricity (kWh)']

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(time[14352:14448],DEcorrect[8141:8237], 'b')
plt.plot(time[14352:14448], Data[14352:14448], 'r--')
plt.grid(which = 'major')
plt.xlabel('TimeStamp (DD-MM HH)', fontsize = 15)
plt.ylabel('Electrical in kWh', fontsize = 18)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.title('Anomaly 3 DE Electrical (kWh)', fontsize = 18)
plt.legend(['After','Before'], fontsize=15)
